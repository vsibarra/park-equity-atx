# %% [markdown]
# ## This notebook takes the Land Use database 2016 file from the Austin Open Data Portal and reduces the file to a usealbe format

# %%
import geopandas as gpd

# %%
councilbound = gpd.read_file('https://data.austintexas.gov/api/geospatial/7sg9-qjmi?method=export&format=GeoJSON')

# %%
councilbound
# Out:
#   created_by modified_b        shape_area time_creat                label  \
# 0     meekss  lockwoodg    502791106.3125   11:00:25   Council District 3
# 1     meekss  lockwoodg  330875387.833984   11:00:26   Council District 4
# 2     meekss  lockwoodg  1290119786.29297   11:00:26   Council District 2
# 3     meekss     meekss   671906365.71875   11:00:25   Council District 5
# 4     meekss  lockwoodg  782496369.109375   11:00:26   Council District 7
# 5     meekss  lockwoodg  348217049.759766   11:00:26   Council District 9
# 6     meekss  lockwoodg   1259874107.7793   11:00:25   Council District 8
# 7     meekss  lockwoodg   1201125484.6582   11:00:26  Council District 10
# 8     meekss     meekss  1395148093.93555   11:00:26   Council District 6
# 9     meekss     meekss  1322341605.34375   11:00:25   Council District 1
#
#                                         council_di_1           date_modif  \
# 0   http://www.austintexas.gov/department/district-3  2016-10-18T00:00:00
# ...

# %%
zones = gpd.read_file('https://data.austintexas.gov/api/geospatial/nuca-fzpt?method=export&format=GeoJSON')

# %%
zones
# Out:
#        prop_id previousge py_owner_i source abs_subdv                entities  \
# 0       100008        300    1600885   None    S13671  0A, 01, 02, 03, 2J, 68
# 1       100012        330    1518342   None    S03168  0A, 01, 02, 03, 2J, 68
# 2       100013        300    1459227   None    S03167  0A, 01, 02, 03, 2J, 68
# 3       100014        300    1709771   None    S03168  0A, 01, 02, 03, 2J, 68
# 4       100015        300     100009   None    S08658  0A, 01, 02, 03, 2J, 68
# ...        ...        ...        ...    ...       ...                     ...
# 265415       0        100          0   None      None                    None
# 265416       0        100          0   None      None                    None
# 265417       0        800          0   None      None                    None
# 265418       0        900          0   None      None                    None
# 265419       0        100          0   None      None                    None
#
# ...
