# %% [markdown]
# # In this notebook we will create service area boundaries for each park managed by the city of austin

# %%
import geopandas as gpd
import os
import getpass
import matplotlib.pyplot as plt
import re
import pandas as pd
wd = os.getcwd()
wd = wd[:wd.find('notebooks')]

# %%
coaparks = gpd.read_file(wd+"data/coaparks/BOUNDARIES_city_of_austin_parks.shp")

#Link to data and metadata: https://data.austintexas.gov/Locations-and-Maps/BOUNDARIES_city_of_austin_parks/8f2b-a4q5

# Separate these before hand! 
coaparks.head(10)
# Out:
#   ASSET_MGMT                             LOCATION_N  \
# 0        412           Stratford Overlook Greenbelt
# 1        413             Highland Neighborhood Park
# 2        354                Palma Plaza Pocket Park
# 3        398               Oertli Neighborhood Park
# 4        370      Decker Tallgrass Prairie Preserve
# 5        364    Peace Point at Town Lake Metro Park
# 6        298  Norwood Tract at Town Lake Metro Park
# 7        204                          Mayfield Park
# 8        187                          Kennemer Pool
# 9        217                     Norman School Park
#
#                                        ADDRESS CITY_MUNIC  COUNTY STATE  \
# 0      3006 Stratford Dr., Austin, Texas 78746     Austin  Travis    TX
# 1     403 W St Johns Ave., Austin, Texas 78752     Austin  Travis    TX
# 2         1524 Palma Plz., Austin, Texas 78703     Austin  Travis    TX
# 3        12613 Blaine Rd., Austin, Texas 78753     Austin  Travis    TX
# 4         8001 Decker Ln., Austin, Texas 78724     Austin  Travis    TX
# 5  2200 S Lakeshore Blvd., Austin, Texas 78741     Austin  Travis    TX
# 6     1009 Edgecliff Ter., Austin, Texas 78704     Austin  Travis    TX
# 7         3805 W 35th St., Austin, Texas 78703     Austin  Travis    TX
# 8     1031 Payton Gin Rd., Austin, Texas 78758     Austin  Travis    TX
# 9      3901 Tannehill Ln., Austin, Texas 78721     Austin  Travis    TX
#
#   STREET_NUM   STREET_NAM STREET_TYP ZIPCODE  ...  MXPRIORITY MXLOADID  \
# 0       3006    Stratford        Dr.   78746  ...           0     None
# 1        403   W St Johns       Ave.   78752  ...           0     None
# 2       1524        Palma        Plz   78703  ...           0     None
# 3      12613       Blaine        Rd.   78753  ...           0     None
# 4       8001       Decker        Ln.   78724  ...           0     None
# 5       2200  S Lakeshore       Blvd   78741  ...           0     None
# 6       1009    Edgecliff        Ter   78704  ...           0     None
# 7       3805       W 35th        St.   78703  ...           0     None
# 8       1031   Payton Gin        Rd.   78758  ...           0     None
# 9       3901    Tannehill        Ln.   78721  ...           0     None
#
#   GLOBALID     CREATED_BY  CREATED_DA     MODIFIED_B  MODIFIED_D  \
# 0     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
# 1     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
# 2     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
# 3     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
# 4     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
# 5     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
# 6     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
# 7     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
# 8     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
# 9     None  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12
#
#      Shape__Are    Shape__Len  \
# 0  4.403262e+03    420.672106
# 1  1.048800e+04    422.279483
# 2  1.007678e+04    492.661534
# 3  2.671883e+05   2404.916487
# 4  1.515843e+07  26672.772067
# 5  2.381281e+05   4343.236948
# 6  4.150892e+05   7283.191248
# 7  1.022823e+06   4794.005509
# 8  4.556303e+04    960.033300
# 9  3.087978e+05   2981.252775
#
#                                             geometry
# 0  POLYGON ((3099906.430145308 10076413.89003989,...
# 1  POLYGON ((3123253.446115226 10095987.26952823,...
# 2  POLYGON ((3109560.790101632 10075621.8601279, ...
# 3  POLYGON ((3142167.801987216 10117512.55423348,...
# 4  POLYGON ((3155053.00948447 10084108.4848869, 3...
# 5  (POLYGON ((3121502.000143051 10063076.00004905...
# 6  (POLYGON ((3115397.693454057 10064828.94175315...
# 7  POLYGON ((3105648.160459712 10086501.19007523,...
# 8  POLYGON ((3125342.31037581 10104470.85984448, ...
# 9  POLYGON ((3135631.310138971 10074747.45013131,...
#
# [10 rows x 54 columns]

# %%
len(coaparks)
# Out:
# 298

# %%
coaparks.columns
# Out:
# Index(['ASSET_MGMT', 'LOCATION_N', 'ADDRESS', 'CITY_MUNIC', 'COUNTY', 'STATE',
#        'STREET_NUM', 'STREET_NAM', 'STREET_TYP', 'ZIPCODE', 'ASSET_SIZE',
#        'ACRE_SOURC', 'UNIT_OF_ME', 'YEAR_ACQUI', 'ASSET_STAT', 'DEVELOPMEN',
#        'TPL_LANDUS', 'PARK_TYPE', 'LEVEL_OF_S', 'LEVEL_OF_U', 'SERVICE_AR',
#        'COUNCIL_DI', 'COUNCIL__1', 'MANAGEMENT', 'OWNER_NAME', 'OWNER_TYPE',
#        'MANAGING_N', 'MANAGING_T', 'ACQUISITIO', 'ACQUISIT_1', 'ACQUISIT_2',
#        'DEVELOPM_1', 'DEVELOPM_2', 'RESTRICTIO', 'LWCF_PROTE', 'OTHER_PROT',
#        'REST_PROT_', 'COMMUNITY_', 'MXASSETNUM', 'MXLOCATION', 'MXSITEID',
#        'MXCREATION', 'MXSTATUS', 'MXCONDITIO', 'MXPRIORITY', 'MXLOADID',
#        'GLOBALID', 'CREATED_BY', 'CREATED_DA', 'MODIFIED_B', 'MODIFIED_D',
#        'Shape__Are', 'Shape__Len', 'geometry'],
#       dtype='object')

# %%
parks_wocem = coaparks[['LOCATION_N', 'ASSET_SIZE','PARK_TYPE','geometry']].copy().reset_index()

# %%
parks_wocem.columns
# Out:
# Index(['index', 'LOCATION_N', 'ASSET_SIZE', 'PARK_TYPE', 'geometry'], dtype='object')

# %%
parks_wocem.PARK_TYPE.unique()
# Out:
# array(['Greenbelt', 'Neighborhood', 'Pocket', 'Nature Preserve',
#        'Metropolitan', 'Special', 'School', 'Planting Strips/Triangles',
#        'District', 'Golf Course'], dtype=object)

# %%
print(parks_wocem['PARK_TYPE'])
# Out:
# 0            Greenbelt
# 1         Neighborhood
# 2               Pocket
# 3         Neighborhood
# 4      Nature Preserve
#             ...
# 293       Neighborhood
# 294       Neighborhood
# 295    Nature Preserve
# 296           District
# 297            Special
# Name: PARK_TYPE, Length: 298, dtype: object

# %%
parks_wocem = parks_wocem[parks_wocem.PARK_TYPE != 'Nature Preserve']
parks_wocem = parks_wocem[parks_wocem.PARK_TYPE!= 'Cemetery']
parks_wocem = parks_wocem[parks_wocem.PARK_TYPE!= 'Golf Course']

# %%
parks_wocem.reset_index()
# Out:
#      level_0  index                           LOCATION_N  ASSET_SIZE  \
# 0          0      0         Stratford Overlook Greenbelt     0.07000
# 1          1      1           Highland Neighborhood Park     0.24100
# 2          2      2              Palma Plaza Pocket Park     0.20660
# 3          3      3             Oertli Neighborhood Park     6.00000
# 4          5      5  Peace Point at Town Lake Metro Park     5.46669
# ..       ...    ...                                  ...         ...
# 273      292    292  South Austin Senior Activity Center     4.63000
# 274      293    293          Red Bluff Neighborhood Park     7.19600
# 275      294    294        MLK Station Neighborhood Park     7.91700
# 276      296    296               Garrison District Park    40.00000
# 277      297    297            Davis Spring Special Park    14.47200
#
#         PARK_TYPE                                           geometry
# 0       Greenbelt  POLYGON ((3099906.430145308 10076413.89003989,...
# 1    Neighborhood  POLYGON ((3123253.446115226 10095987.26952823,...
# 2          Pocket  POLYGON ((3109560.790101632 10075621.8601279, ...
# 3    Neighborhood  POLYGON ((3142167.801987216 10117512.55423348,...
# 4    Metropolitan  (POLYGON ((3121502.000143051 10063076.00004905...
# ..            ...                                                ...
# 273       Special  POLYGON ((3101202.759901717 10058230.16033131,...
# 274  Neighborhood  POLYGON ((3135145.072922468 10071838.69512206,...
# 275  Neighborhood  POLYGON ((3125001.803182796 10074460.76008789,...
# 276      District  POLYGON ((3096438.9803873 10050515.35030164, 3...
# 277       Special  POLYGON ((3104769.340366974 10150475.19696948,...
#
# [278 rows x 6 columns]

# %%
#parks_wocem.LOCATION_N.unique()

# %% [markdown]
# ## Creation of buffers of for 1/4 mile (1320 ft) and 1/2 a mile (2640 ft) and Varied based  on size or type of Park
#    #### Exclude cemetries from the park counts
#    #### For the variable buffers follow the guidelines below

# %%
coaparks_quarter = parks_wocem.copy()
coaparks_half = parks_wocem.copy()

coaparks_quarter['geometry'] = coaparks_quarter['geometry'].buffer(1320)
coaparks_half['geometry'] = coaparks_half['geometry'].buffer(2640)
    
#neighborhood = .5 between 2 and 30 acres
#pocket = .25 <2acres
#district = 1 31 < acres < 200
#greenbelt = 5 look in Names 
#metro = 5  >200 acres 
#schools Look in Names

# series.loc[indexer]
# df.loc[row.indexer, column.indexer]
coaparks_vari = parks_wocem.copy()
num_neigh = 0
num_pocket = 0
num_district=0
num_greenbelt = 0
num_metro=0
num_schools = 0
num_special = 0
num_cem=0
num_perserve = 0


for row in coaparks_vari['ASSET_SIZE'].index:
    if coaparks_vari['ASSET_SIZE'][row] < 2:
        # The record is a pocket park, we buffer by .25 mile
        coaparks_vari['geometry'].loc[row] = coaparks_vari['geometry'].loc[row].buffer(1320)
        num_pocket += 1
        
    if coaparks_vari['ASSET_SIZE'][row] >= 2 and coaparks_vari['ASSET_SIZE'][row] <= 30:
        # The record is a neighborhood park, thus buffer by 1 mile
        coaparks_vari['geometry'].loc[row] = coaparks_vari['geometry'].loc[row].buffer(5280)
        num_neigh += 1
    
    if coaparks_vari['ASSET_SIZE'][row] >= 31 and coaparks_vari['ASSET_SIZE'][row] <= 200:
        # This record is a district park, thus buffer is 2 mile
        coaparks_vari['geometry'].loc[row] = coaparks_vari['geometry'].loc[row].buffer(10560)
        num_district += 1
        
    if coaparks_vari['ASSET_SIZE'][row] > 200:
        # This record is a metro, thus buffer is 5 mile
        coaparks_vari['geometry'].loc[row] = coaparks_vari['geometry'].loc[row].buffer(26400)
        num_metro += 1
    
    if 'School' in coaparks['PARK_TYPE'][row]:
        # School parks are given a .25 mile buffer
        coaparks_vari['geometry'].loc[row] = coaparks['geometry'].loc[row].buffer(1320)
        num_schools += 1
    
    if 'Special' in coaparks['PARK_TYPE'][row]:
        # Special parks are given a .25 mile buffer
        coaparks_vari['geometry'].loc[row] = coaparks['geometry'].loc[row].buffer(1320)
        num_special += 1    
    
    if 'Greenbelt' in coaparks['PARK_TYPE'][row]:
        # We want to make sure we check that all of the greenblets are buffered 
        coaparks_vari['geometry'].loc[row] = coaparks['geometry'].loc[row].buffer(10560)
        num_greenbelt +=1
    
    if 'Nature Preserve' in coaparks['PARK_TYPE'][row]:
        coaparks_vari.drop('Nature Preserve', inplace=True)
        num_perserve +=1
    
    
    if 'Cemetery' in coaparks['PARK_TYPE'][row]: 
        coaparks_vari.drop('Cemetery', inplace=True)
        num_cem +=1
        
        
print('pocket', num_pocket)
print('neigh', num_neigh)
print('district', num_district)
print('metro', num_metro)
print('greenbelt', num_greenbelt)
print('school', num_schools)
print('preserve', num_perserve)
print('cemetery', num_cem)
# Out:
# C:\Users\Victoria\Anaconda3\envs\park_env\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# pocket 57
# neigh 163
# district 40
# metro 17
# greenbelt 50
# school 22
# preserve 0
# cemetery 0

# %%
coaparks_vari
# Out:
#      index                           LOCATION_N  ASSET_SIZE     PARK_TYPE  \
# 0        0         Stratford Overlook Greenbelt     0.07000     Greenbelt
# 1        1           Highland Neighborhood Park     0.24100  Neighborhood
# 2        2              Palma Plaza Pocket Park     0.20660        Pocket
# 3        3             Oertli Neighborhood Park     6.00000  Neighborhood
# 5        5  Peace Point at Town Lake Metro Park     5.46669  Metropolitan
# ..     ...                                  ...         ...           ...
# 292    292  South Austin Senior Activity Center     4.63000       Special
# 293    293          Red Bluff Neighborhood Park     7.19600  Neighborhood
# 294    294        MLK Station Neighborhood Park     7.91700  Neighborhood
# 296    296               Garrison District Park    40.00000      District
# 297    297            Davis Spring Special Park    14.47200       Special
#
#                                               geometry
# 0    POLYGON ((3093382.105579928 10068110.4697226, ...
# 1    POLYGON ((3122096.607847079 10096622.97796875,...
# 2    POLYGON ((3110574.911703501 10076479.19303526,...
# 3    POLYGON ((3139954.891922666 10112725.14427203,...
# 5    POLYGON ((3125344.080527302 10059285.06139334,...
# ..                                                 ...
# 292  POLYGON ((3100022.22821556 10058820.70663599, ...
# 293  POLYGON ((3129808.692370967 10072890.00266177,...
# 294  POLYGON ((3119777.931476575 10076605.04379445,...
# 296  POLYGON ((3090172.37347961 10040922.11961293, ...
# 297  POLYGON ((3104793.917756151 10148314.72718683,...
#
# [278 rows x 5 columns]

# %%
len(coaparks_vari)
# Out:
# 278

# %%
fig, ax = plt.subplots(figsize=(20,20))
coaparks_vari.plot(ax = ax, color='red')
coaparks_half.plot(ax=ax, color='blue')
coaparks_quarter.plot(ax=ax, color='cyan')
coaparks.plot(ax=ax, color='grey');

# %% [markdown]
# ## Take the difference between the park shapefile and the buffers to create a buffer shapefile that has all the attributes of the park data but does not include the park in the geometry

# %%
quarterdif = coaparks.copy()
halfdif = coaparks.copy()
varidif = coaparks.copy()

#coaparks_quarter=gpd.GeoDataFrame(coaparks.buffer(400))
#coaparks_quarter=coaparks_quarter.rename(columns={0:'geometry'})

#coaparks_half=gpd.GeoDataFrame(coaparks.buffer(800))
#coaparks_half=coaparks_half.rename(columns={0:'geometry'})

# %%
quarterdif['geometry'] = gpd.overlay(coaparks_quarter, coaparks, how='difference')['geometry']
halfdif['geometry'] = gpd.overlay(coaparks_half, coaparks, how='difference')['geometry']
varidif['geometry'] = gpd.overlay(coaparks_vari, coaparks, how='difference')['geometry']
quarterdif = gpd.GeoDataFrame(quarterdif)

# %%
varidif=varidif.dropna(subset=['geometry'])
quarterdif=quarterdif.dropna(subset=['geometry'])
halfdif=halfdif.dropna(subset=['geometry'])

# %% [markdown]
# ### Export all three buffer shapefiles. The shapefils can then be uploaded into QGIS and changed into geojson files with a WGS 84

# %%
quarterdif.to_file(wd+"data/coaparks_buffer/quarterbuff.shp")
halfdif.to_file(wd+"data/coaparks_buffer/halfbuff.shp")
varidif.to_file(wd+"data/coaparks_buffer/varibuff.shp")

# %% [markdown]
# ### Unused Code

# %%
#coaparks_quarter['geometry'].loc[row] = coaparks['geometry'].loc[row]
#plot
#fig, ax = plt.subplots(figsize=(20,20))
#vastra.plot(ax=ax)
#coaparks_half.plot(ax=ax, color='blue')
#coaparks_quarter.plot(ax=ax, color='cyan')
#coaparks.plot(ax=ax, color='grey');

#fig5, ax = plt.subplots(figsize=(12,12))
#base = coaparks.plot(ax=ax, color="black", alpha=0.2)
#layer = coaparks["geometry"].plot(ax=base, color='black', edgecolor = 'black')

#fig6, ax = plt.subplots(figsize=(12,12))
#base = quarterdif.plot(ax=ax, color="black", alpha=0.2)
#layer = quarterdif["geometry"].plot(ax=base, color='black', edgecolor = 'black')


#Export to geojson
#coaparks_half.to_file(wd+"data/coaparks_buffer/halfbuff.geojson")
#coaparks_quarter.to_file(wd+"data/coaparks_buffer/quarterbuff.geojson")
#coaparks_vari.to_file(wd+"data/coaparks_buffer/varibuff.geojson")
