# %%
import geopandas as gpd
import pandas as pd
import os
import getpass
import matplotlib.pyplot as plt
from earthpy.clip import clip_shp

# %% [markdown]
# ### NOTES:

# %% [markdown]
# ###### Bring in necessary geojson files and set your projection for all files

# %%
wd = os.getcwd()
wd = wd[:wd.find('notebooks')]

#crs is set for Central Texas; https://epsg.io/6578; 
crs =  {'init' :'epsg:6578'}

#parks = gpd.read_file(wd+"data/coaparks/parkboundaries.geojson")
#parks = parks.to_crs(crs).explode().reset_index()

quartbuff = gpd.read_file(wd+"data/coaparks_buffer/quarterbuff.shp")
quartbuff.crs={'init' :'epsg:6578'}

pop = gpd.read_file(wd+"data/blockgroups_censusdata/popmerge.shp")
pop = pop.to_crs(crs).reset_index()

race = gpd.read_file(wd+"data/blockgroups_censusdata/racemerge.shp")
race = race.to_crs(crs).reset_index()

income = gpd.read_file(wd+"data/blockgroups_censusdata/incomemerge.shp")
income = income.to_crs(crs).reset_index()

# %% [markdown]
# ##### Check your projections
# https://geopandas.org/projections.html

# %%
#parks.crs

# %%
quartbuff.crs
# Out:
# {'init': 'epsg:6578'}

# %%
pop.crs
# Out:
# {'init': 'epsg:6578'}

# %%
race.crs
# Out:
# {'init': 'epsg:6578'}

# %% [markdown]
# ###### Preview the files and clean the data

# %%
pop['fullarea_pop'] = pop['geometry'].area
pop.head()
# Out:
#    index       GEOID10   ALAND10  AWATER10   INTPTLAT10    INTPTLON10  \
# 0      0  482090109011  291268.0       0.0  +30.1776997  -097.9267996
# 1      1  482090109081  142299.0       0.0  +30.0960389  -097.8116716
# 2      2  484530001011   17128.0       0.0  +30.3353452  -097.7546582
# 3      3  484530001012   43720.0       0.0  +30.3247732  -097.7516364
# 4      4  484530001013  415563.0       0.0  +30.3158528  -097.7515898
#
#         city_name           jurisdicti                     Id           Id2  \
# 0  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109011  482090109011
# 1  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109081  482090109081
# 2  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001011  484530001011
# 3  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001012  484530001012
# 4  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001013  484530001013
#
#    Total_POP                                           geometry  fullarea_pop
# 0       2205  (POLYGON ((3069238.317597141 10028016.9612432,...  2.280497e+07
# 1       3774  POLYGON ((3093548.488136804 10008631.07120929,...  1.837684e+03
# 2       1045  POLYGON ((3111310.380106392 10089474.08471978,...  1.023445e+07
# 3       1202  POLYGON ((3109356.370562974 10091521.99532213,...  1.190644e+07
# 4       2016  POLYGON ((3110878.498096142 10085236.13059729,...  1.151098e+07

# %%
race['fullarea_race'] = race['geometry'].area
race.head()
# Out:
#    index       GEOID10   ALAND10  AWATER10   INTPTLAT10    INTPTLON10  \
# 0      0  482090109011  291268.0       0.0  +30.1776997  -097.9267996
# 1      1  482090109081  142299.0       0.0  +30.0960389  -097.8116716
# 2      2  484530001011   17128.0       0.0  +30.3353452  -097.7546582
# 3      3  484530001012   43720.0       0.0  +30.3247732  -097.7516364
# 4      4  484530001013  415563.0       0.0  +30.3158528  -097.7515898
#
#         city_name           jurisdicti                     Id           Id2  \
# 0  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109011  482090109011
# 1  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109081  482090109081
# 2  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001011  484530001011
# 3  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001012  484530001012
# 4  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001013  484530001013
#
#    ...  Black or A  American I  Asian; Not  Native Haw  Some other  \
# 0  ...           0           0          40          78           0
# 1  ...          91           0          80           0           0
# 2  ...          26           0           0           0           0
# 3  ...           0          14           0           0           0
# 4  ...           0           0          70           0           0
#
#    Two or mor  Hispanic o  Sum of Non  \
# 0          34         421        2205
# 1          16        2507        3774
# 2          20         113        1045
# 3          42         121        1202
# 4          39         163        2016
#
#                                             geometry  fullarea_race
# 0  (POLYGON ((3069238.317597141 10028016.9612432,...   2.280497e+07
# 1  POLYGON ((3093548.488136804 10008631.07120929,...   1.837684e+03
# 2  POLYGON ((3111310.380106392 10089474.08471978,...   1.023445e+07
# 3  POLYGON ((3109356.370562974 10091521.99532213,...   1.190644e+07
# 4  POLYGON ((3110878.498096142 10085236.13059729,...   1.151098e+07
#
# [5 rows x 23 columns]

# %%
income['fullarea_income'] = income['geometry'].area
income.head()
# Out:
#    index       GEOID10   ALAND10  AWATER10   INTPTLAT10    INTPTLON10  \
# 0      0  482090109011  291268.0       0.0  +30.1776997  -097.9267996
# 1      1  482090109081  142299.0       0.0  +30.0960389  -097.8116716
# 2      2  484530001011   17128.0       0.0  +30.3353452  -097.7546582
# 3      3  484530001012   43720.0       0.0  +30.3247732  -097.7516364
# 4      4  484530001013  415563.0       0.0  +30.3158528  -097.7515898
#
#         city_name           jurisdicti                     Id           Id2  \
# 0  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109011  482090109011
# 1  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109081  482090109081
# 2  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001011  484530001011
# 3  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001012  484530001012
# 4  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001013  484530001013
#
#    ...  $45,000 to  $50,000 to  $60,000 to  $75,000 to  $100,000 t  \
# 0  ...          19          47          51          64         128
# 1  ...         123          61         168         215         118
# 2  ...           5          19          42          56          48
# 3  ...           6          23          63          15          31
# 4  ...          15         124         116          94         100
#
#    $125,000 t  $150,000 t  $200,000 o  \
# 0          42          76         220
# 1          72          84          18
# 2           9          71          72
# 3          19          92         206
# 4         154         101         117
#
#                                             geometry  fullarea_income
# 0  (POLYGON ((3069238.317597141 10028016.9612432,...     2.280497e+07
# 1  POLYGON ((3093548.488136804 10008631.07120929,...     1.837684e+03
# 2  POLYGON ((3111310.380106392 10089474.08471978,...     1.023445e+07
# 3  POLYGON ((3109356.370562974 10091521.99532213,...     1.190644e+07
# 4  POLYGON ((3110878.498096142 10085236.13059729,...     1.151098e+07
#
# [5 rows x 29 columns]

# %%
quartbuff['fullarea_buff'] = quartbuff['geometry'].area
quartbuff.head()
# Out:
#   ASSET_MGMT                         LOCATION_N  \
# 0        412       Stratford Overlook Greenbelt
# 1        413         Highland Neighborhood Park
# 2        354            Palma Plaza Pocket Park
# 3        398           Oertli Neighborhood Park
# 4        370  Decker Tallgrass Prairie Preserve
#
#                                     ADDRESS CITY_MUNIC  COUNTY STATE  \
# 0   3006 Stratford Dr., Austin, Texas 78746     Austin  Travis    TX
# 1  403 W St Johns Ave., Austin, Texas 78752     Austin  Travis    TX
# 2      1524 Palma Plz., Austin, Texas 78703     Austin  Travis    TX
# 3     12613 Blaine Rd., Austin, Texas 78753     Austin  Travis    TX
# 4      8001 Decker Ln., Austin, Texas 78724     Austin  Travis    TX
#
#   STREET_NUM  STREET_NAM STREET_TYP ZIPCODE  ...  MXLOADID GLOBALID  \
# 0       3006   Stratford        Dr.   78746  ...      None     None
# 1        403  W St Johns       Ave.   78752  ...      None     None
# 2       1524       Palma        Plz   78703  ...      None     None
# 3      12613      Blaine        Rd.   78753  ...      None     None
# 4       8001      Decker        Ln.   78724  ...      None     None
#
#       CREATED_BY  CREATED_DA     MODIFIED_B  MODIFIED_D    Shape__Are  \
# 0  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  4.403262e+03
# 1  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  1.048800e+04
# 2  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  1.007678e+04
# 3  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  2.671883e+05
# 4  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  1.515843e+07
#
#      Shape__Len                                           geometry  \
# 0    420.672106  POLYGON ((3099659.296639044 10076099.36654302,...
# 1    422.279483  POLYGON ((3122902.889064272 10096179.9084496, ...
# 2    492.661534  POLYGON ((3109810.268547321 10075962.94345399,...
# 3   2404.916487  POLYGON ((3142020.189037629 10117140.78761702,...
# 4  26672.772067  POLYGON ((3154723.006204365 10083882.87548335,...
#
#   fullarea_buff
# 0  6.701295e+05
# 1  6.708336e+05
# 2  6.988492e+05
# 3  1.463807e+06
# 4  9.294015e+06
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Run spatial analysis on the amount of people distributed within a census block group against the quarter mile park buffer area and the race census data

# %%
rp_intersection = gpd.overlay(race, quartbuff, how='intersection') #https://geopandas.org/set_operations.html
rp_intersection['area_intersec'] = rp_intersection['geometry'].area
rp_intersection.to_file(wd+"data/access/rp_intersec_quarterbuff_ACS17.shp")
rp_intersection
# Out:
#       index       GEOID10   ALAND10  AWATER10   INTPTLAT10    INTPTLON10  \
# 2         2  484530001011   17128.0       0.0  +30.3353452  -097.7546582
# 7         4  484530001013  415563.0       0.0  +30.3158528  -097.7515898
# 21        8  484530002041   57831.0       0.0  +30.3027360  -097.7413860
# 24        9  484530002042   16538.0       0.0  +30.3162020  -097.7451126
# 30       10  484530002043   61172.0       0.0  +30.3084751  -097.7470902
# ...     ...           ...       ...       ...          ...           ...
# 1546    542  484910204083   34157.0       0.0  +30.4530947  -097.7811364
# 1544    540  484910204081    9762.0       0.0  +30.4597401  -097.7933842
# 1547    552  484910205081  636722.0     850.0  +30.4840639  -097.7595422
# 1551    556  484910205101    2092.0       0.0  +30.4950296  -097.7673875
# 1553    557  484910205103   14153.0       0.0  +30.4953417  -097.7716305
#
#            city_name           jurisdicti                     Id  \
# 2     CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001011
# 7     CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001013
# 21    CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530002041
# 24    CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530002042
# 30    CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530002043
# ...              ...                  ...                    ...
# 1546  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484910204083
# 1544  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484910204081
# 1547  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484910205081
# 1551  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484910205101
# 1553  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484910205103
#
#                Id2  ...  GLOBALID     CREATED_BY  CREATED_DA     MODIFIED_B  \
# 2     484530001011  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
# 7     484530001013  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
# 21    484530002041  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
# 24    484530002042  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
# 30    484530002043  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
# ...            ...  ...       ...            ...         ...            ...
# 1546  484910204083  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
# 1544  484910204081  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
# 1547  484910205081  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
# 1551  484910205101  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
# 1553  484910205103  ...      None  CTM.Publisher  2019-10-12  CTM.Publisher
#
#       MODIFIED_D    Shape__Are    Shape__Len  fullarea_buff  \
# 2     2019-10-12  3.514350e+06  56641.286637   2.083222e+07
# 7     2019-10-12  3.514350e+06  56641.286637   2.083222e+07
# 21    2019-10-12  3.514350e+06  56641.286637   2.083222e+07
# 24    2019-10-12  3.514350e+06  56641.286637   2.083222e+07
# 30    2019-10-12  3.514350e+06  56641.286637   2.083222e+07
# ...          ...           ...           ...            ...
# 1546  2019-10-12  5.423833e+05   2970.882179   1.690157e+06
# 1544  2019-10-12  9.810471e+04   1492.002528   1.070334e+06
# 1547  2019-10-12  6.289057e+05   3819.975953   1.976420e+06
# 1551  2019-10-12  6.289057e+05   3819.975953   1.976420e+06
# 1553  2019-10-12  6.289057e+05   3819.975953   1.976420e+06
#
#                                                geometry  area_intersec
# 2     (POLYGON ((3112577.691601556 10092106.43546127...   1.937863e+06
# 7     (POLYGON ((3111956.64230204 10087345.37179527,...   1.598405e+06
# 21    POLYGON ((3112579.183619359 10081465.39038167,...   4.060094e+05
# 24    (POLYGON ((3112506.819622439 10086223.64617552...   8.211498e+05
# 30    (POLYGON ((3112746.76010764 10081979.97962928,...   1.578661e+06
# ...                                                 ...            ...
# 1546  POLYGON ((3099958.623058978 10137136.64832762,...   1.043275e+05
# 1544  POLYGON ((3100175.699942151 10143570.94554518,...   8.736948e+05
# 1547  (POLYGON ((3104261.391998203 10149293.93935596...   1.688160e+05
# 1551  POLYGON ((3105146.529438308 10149196.16067607,...   1.681954e+06
# 1553  (POLYGON ((3104692.752993943 10150897.72012688...   1.256484e+05
#
# [927 rows x 78 columns]

# %%
rp_intersection.crs
# Out:
# {'init': 'epsg:6578'}

# %%
rp_intersection.columns
# Out:
# Index(['index', 'GEOID10', 'ALAND10', 'AWATER10', 'INTPTLAT10', 'INTPTLON10',
#        'city_name', 'jurisdicti', 'Id', 'Id2', 'Total_POP', 'Not Hispan',
#        'White; Not', 'Black or A', 'American I', 'Asian; Not', 'Native Haw',
#        'Some other', 'Two or mor', 'Hispanic o', 'Sum of Non', 'fullarea_race',
#        'ASSET_MGMT', 'LOCATION_N', 'ADDRESS', 'CITY_MUNIC', 'COUNTY', 'STATE',
#        'STREET_NUM', 'STREET_NAM', 'STREET_TYP', 'ZIPCODE', 'ASSET_SIZE',
#        'ACRE_SOURC', 'UNIT_OF_ME', 'YEAR_ACQUI', 'ASSET_STAT', 'DEVELOPMEN',
#        'TPL_LANDUS', 'PARK_TYPE', 'LEVEL_OF_S', 'LEVEL_OF_U', 'SERVICE_AR',
#        'COUNCIL_DI', 'COUNCIL__1', 'MANAGEMENT', 'OWNER_NAME', 'OWNER_TYPE',
#        'MANAGING_N', 'MANAGING_T', 'ACQUISITIO', 'ACQUISIT_1', 'ACQUISIT_2',
#        'DEVELOPM_1', 'DEVELOPM_2', 'RESTRICTIO', 'LWCF_PROTE', 'OTHER_PROT',
#        'REST_PROT_', 'COMMUNITY_', 'MXASSETNUM', 'MXLOCATION', 'MXSITEID',
#        'MXCREATION', 'MXSTATUS', 'MXCONDITIO', 'MXPRIORITY', 'MXLOADID',
#        'GLOBALID', 'CREATED_BY', 'CREATED_DA', 'MODIFIED_B', 'MODIFIED_D',
#        'Shape__Are', 'Shape__Len', 'fullarea_buff', 'geometry',
#        'area_intersec'],
#       dtype='object')

# %%
rp_intersection[['GEOID10','Total_POP','fullarea_race','LOCATION_N','fullarea_buff','area_intersec','geometry']]
# Out:
#            GEOID10  Total_POP  fullarea_race                      LOCATION_N  \
# 2     484530001011       1045   1.023445e+07           Shoal Creek Greenbelt
# 7     484530001013       2016   1.151098e+07           Shoal Creek Greenbelt
# 21    484530002041       1113   5.533474e+06           Shoal Creek Greenbelt
# 24    484530002042       1255   5.936942e+06           Shoal Creek Greenbelt
# 30    484530002043        692   8.170845e+06           Shoal Creek Greenbelt
# ...            ...        ...            ...                             ...
# 1546  484910204083        835   9.487768e+05   Springwoods Neighborhood Park
# 1544  484910204081       1797   1.660166e+07  Forest North Neighborhood Park
# 1547  484910205081       3775   3.682212e+07       Davis Spring Special Park
# 1551  484910205101       4695   3.462268e+07       Davis Spring Special Park
# 1553  484910205103        929   3.727163e+06       Davis Spring Special Park
#
#       fullarea_buff  area_intersec  \
# 2      2.083222e+07   1.937863e+06
# 7      2.083222e+07   1.598405e+06
# 21     2.083222e+07   4.060094e+05
# 24     2.083222e+07   8.211498e+05
# 30     2.083222e+07   1.578661e+06
# ...             ...            ...
# 1546   1.690157e+06   1.043275e+05
# 1544   1.070334e+06   8.736948e+05
# 1547   1.976420e+06   1.688160e+05
# 1551   1.976420e+06   1.681954e+06
# 1553   1.976420e+06   1.256484e+05
#
#                                                geometry
# 2     (POLYGON ((3112577.691601556 10092106.43546127...
# 7     (POLYGON ((3111956.64230204 10087345.37179527,...
# 21    POLYGON ((3112579.183619359 10081465.39038167,...
# 24    (POLYGON ((3112506.819622439 10086223.64617552...
# 30    (POLYGON ((3112746.76010764 10081979.97962928,...
# ...                                                 ...
# 1546  POLYGON ((3099958.623058978 10137136.64832762,...
# 1544  POLYGON ((3100175.699942151 10143570.94554518,...
# 1547  (POLYGON ((3104261.391998203 10149293.93935596...
# 1551  POLYGON ((3105146.529438308 10149196.16067607,...
# 1553  (POLYGON ((3104692.752993943 10150897.72012688...
#
# [927 rows x 7 columns]

# %%
race_clip=rp_intersection.copy().reset_index()

for val in race_clip:

    race_clip['weight'] = race_clip['area_intersec']/ race_clip['fullarea_race']
    
    race_clip['access_pop'] = race_clip['weight'] * race_clip['Total_POP']
    race_clip['access_nonhis'] = race_clip['weight'] * race_clip['Not Hispan']
    race_clip['access_white'] = race_clip['weight'] * race_clip['White; Not']
    race_clip['access_his_lat'] = race_clip['weight'] * race_clip['Hispanic o']

race_clip.head()
# Out:
#    level_0  index       GEOID10   ALAND10  AWATER10   INTPTLAT10  \
# 0        2      2  484530001011   17128.0       0.0  +30.3353452
# 1        7      4  484530001013  415563.0       0.0  +30.3158528
# 2       21      8  484530002041   57831.0       0.0  +30.3027360
# 3       24      9  484530002042   16538.0       0.0  +30.3162020
# 4       30     10  484530002043   61172.0       0.0  +30.3084751
#
#      INTPTLON10       city_name           jurisdicti                     Id  \
# 0  -097.7546582  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001011
# 1  -097.7515898  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001013
# 2  -097.7413860  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530002041
# 3  -097.7451126  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530002042
# 4  -097.7470902  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530002043
#
#    ...    Shape__Are    Shape__Len  fullarea_buff  \
# 0  ...  3.514350e+06  56641.286637   2.083222e+07
# 1  ...  3.514350e+06  56641.286637   2.083222e+07
# 2  ...  3.514350e+06  56641.286637   2.083222e+07
# 3  ...  3.514350e+06  56641.286637   2.083222e+07
# 4  ...  3.514350e+06  56641.286637   2.083222e+07
#
#                                             geometry  area_intersec    weight  \
# 0  (POLYGON ((3112577.691601556 10092106.43546127...   1.937863e+06  0.189347
# 1  (POLYGON ((3111956.64230204 10087345.37179527,...   1.598405e+06  0.138859
# 2  POLYGON ((3112579.183619359 10081465.39038167,...   4.060094e+05  0.073373
# 3  (POLYGON ((3112506.819622439 10086223.64617552...   8.211498e+05  0.138312
# 4  (POLYGON ((3112746.76010764 10081979.97962928,...   1.578661e+06  0.193207
#
#    access_pop  access_nonhis  access_white  access_his_lat
# 0  197.867768     176.471541    167.761572       21.396228
# 1  279.940023     257.305983    242.170337       22.634040
# 2   81.664523      70.071536     59.359029       11.592987
# 3  173.581460     152.419736    138.450232       21.161724
# 4  133.698975     109.354942     92.159554       24.344033
#
# [5 rows x 84 columns]

# %%
race_clip.columns
# Out:
# Index(['level_0', 'index', 'GEOID10', 'ALAND10', 'AWATER10', 'INTPTLAT10',
#        'INTPTLON10', 'city_name', 'jurisdicti', 'Id', 'Id2', 'Total_POP',
#        'Not Hispan', 'White; Not', 'Black or A', 'American I', 'Asian; Not',
#        'Native Haw', 'Some other', 'Two or mor', 'Hispanic o', 'Sum of Non',
#        'fullarea_race', 'ASSET_MGMT', 'LOCATION_N', 'ADDRESS', 'CITY_MUNIC',
#        'COUNTY', 'STATE', 'STREET_NUM', 'STREET_NAM', 'STREET_TYP', 'ZIPCODE',
#        'ASSET_SIZE', 'ACRE_SOURC', 'UNIT_OF_ME', 'YEAR_ACQUI', 'ASSET_STAT',
#        'DEVELOPMEN', 'TPL_LANDUS', 'PARK_TYPE', 'LEVEL_OF_S', 'LEVEL_OF_U',
#        'SERVICE_AR', 'COUNCIL_DI', 'COUNCIL__1', 'MANAGEMENT', 'OWNER_NAME',
#        'OWNER_TYPE', 'MANAGING_N', 'MANAGING_T', 'ACQUISITIO', 'ACQUISIT_1',
#        'ACQUISIT_2', 'DEVELOPM_1', 'DEVELOPM_2', 'RESTRICTIO', 'LWCF_PROTE',
#        'OTHER_PROT', 'REST_PROT_', 'COMMUNITY_', 'MXASSETNUM', 'MXLOCATION',
#        'MXSITEID', 'MXCREATION', 'MXSTATUS', 'MXCONDITIO', 'MXPRIORITY',
#        'MXLOADID', 'GLOBALID', 'CREATED_BY', 'CREATED_DA', 'MODIFIED_B',
#        'MODIFIED_D', 'Shape__Are', 'Shape__Len', 'fullarea_buff', 'geometry',
#        'area_intersec', 'weight', 'access_pop', 'access_nonhis',
#        'access_white', 'access_his_lat'],
#       dtype='object')

# %%
race_calc = race_clip[['LOCATION_N', 'access_pop', 'access_nonhis','access_white', 'access_his_lat','geometry']]

access_data = race_calc.dissolve(by='LOCATION_N', aggfunc='sum')
access_data.to_file(wd+"data/access/access_data_race_ACS17.shp")
access_data
# Out:
#                                                                            geometry  \
# LOCATION_N
# A.B. Dittmar Neighborhood Park    POLYGON ((3097020.310937755 10040423.29635413,...
# Adams-Hemphill Neighborhood Park  POLYGON ((3115850.357792675 10080502.90460191,...
# Agave Neighborhood Park           POLYGON ((3144770.981680033 10080963.49225345,...
# Alamo Pocket Park                 POLYGON ((3121188.167724669 10076733.3592437, ...
# Alderbrook Pocket Park            POLYGON ((3127839.866424789 10124813.31840664,...
# ...                                                                             ...
# Wunneburger Neighborhood Park     (POLYGON ((3095156.226719216 10021252.69393206...
# Yates Pocket Park                 POLYGON ((3128393.558881322 10059201.38858544,...
# Yett Creek Neighborhood Park      POLYGON ((3117185.845495133 10129921.9187002, ...
# Zilker Metro Park                 (POLYGON ((3105748.96466563 10067644.87424662,...
# Zilker Nature Preserve            (POLYGON ((3102890.662981461 10071741.5256621,...
#
#                                    access_pop  access_nonhis  access_white  \
# LOCATION_N
# A.B. Dittmar Neighborhood Park     247.977755     162.079414    128.683162
# Adams-Hemphill Neighborhood Park  1354.176164    1170.820941    935.254003
# Agave Neighborhood Park            335.671533      54.503339     31.352479
# Alamo Pocket Park                  115.493875     105.121175     59.412007
# Alderbrook Pocket Park             351.309776     247.539393    206.342036
# ...                                       ...            ...           ...
# Wunneburger Neighborhood Park        1.153109       0.701316      0.596572
# Yates Pocket Park                  181.522781      77.983533     24.206194
# Yett Creek Neighborhood Park       164.411123     147.521425    138.145237
# Zilker Metro Park                  664.774783     608.525777    543.164192
# Zilker Nature Preserve             168.771660     158.385914    124.562163
#
#                                   access_his_lat
# LOCATION_N
# A.B. Dittmar Neighborhood Park         85.898341
# Adams-Hemphill Neighborhood Park      183.355223
# Agave Neighborhood Park               281.168194
# Alamo Pocket Park                      10.372700
# Alderbrook Pocket Park                103.770383
# ...                                          ...
# Wunneburger Neighborhood Park           0.451794
# Yates Pocket Park                     103.539248
# Yett Creek Neighborhood Park           16.889699
# Zilker Metro Park                      56.249006
# Zilker Nature Preserve                 10.385746
#
# [290 rows x 5 columns]

# %%
access_data.crs
# Out:
# {'init': 'epsg:6578'}

# %%
access_data.columns
# Out:
# Index(['geometry', 'access_pop', 'access_nonhis', 'access_white',
#        'access_his_lat'],
#       dtype='object')

# %% [markdown]
# #### A dataframe is created with the 'acess_data' geoshapefile. This dataframe is cleaned up and the values are convereted into integers. Finally, we export the dataframe into a csv file and a shapefile.

# %%
df = pd.DataFrame(access_data)
df['Total_Pop'] = df['access_pop'].astype(int)
df['Non_Hispan'] = df['access_nonhis'].astype(int)
df['White'] = df['access_white'].astype(int)
df['Hispan_Latin'] = df['access_his_lat'].astype(int)

access_race = df.drop(columns=['access_pop','access_nonhis','access_white','access_his_lat'])
access_race = gpd.GeoDataFrame(access_race geometry='geometry')
access_race_final = access_race_final.merge(quartbuff, on='geometry')
cities_with_country = geopandas.sjoin(cities, countries, how="inner", op='intersects')v
access_race_final.to_file(wd+"data/access/access_race_final_ACS17.shp")


#cities_with_country = geopandas.sjoin(cities, countries, how="inner", op='intersects')


#access_racetable = df.drop(columns=['LOCATION_N','access_pop','access_nonhis','access_white','access_his_lat','geometry'])
#access_racetable.to_csv(wd+"data/access/access_table_race_ACS17.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4c524dbe319d> in <module>
#       7 access_race_final = df.drop(columns=['access_pop','access_nonhis','access_white','access_his_lat'])
#       8 access_race_final = gpd.GeoDataFrame(access_race_final, geometry='geometry')
# ----> 9 access_race_final = access_race_final.merge(quartbuff, on='geometry')
#      10 access_race_final.to_file(wd+"data/access/access_race_final_ACS17.shp")
#      11
#
# ~\Anaconda3\envs\park_env\lib\site-packages\geopandas\geodataframe.py in merge(self, *args, **kwargs)
#     473
#     474     def merge(self, *args, **kwargs):
# --> 475         result = DataFrame.merge(self, *args, **kwargs)
#     476         geo_col = self._geometry_column_name
#     477         if isinstance(result, DataFrame) and geo_col in result:
#
# ~\Anaconda3\envs\park_env\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7347             copy=copy,
#    7348             indicator=indicator,
# -> 7349             validate=validate,
#    7350         )
#    7351
#
# ~\Anaconda3\envs\park_env\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      81         validate=validate,
#      82     )
# ---> 83     return op.get_result()
#      84
#      85
#
# ~\Anaconda3\envs\park_env\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     640             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     641
# --> 642         join_index, left_indexer, right_indexer = self._get_join_info()
#     643
#     644         ldata, rdata = self.left._data, self.right._data
#
# ~\Anaconda3\envs\park_env\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     857             )
#     858         else:
# --> 859             (left_indexer, right_indexer) = self._get_join_indexers()
#     860
#     861             if self.right_index:
#
# ~\Anaconda3\envs\park_env\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     836         """ return the join indexers """
#     837         return _get_join_indexers(
# --> 838             self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     839         )
#     840
#
# ~\Anaconda3\envs\park_env\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1302
#    1303     # get left & right join labels and num. of levels at each location
# -> 1304     llab, rlab, shape = map(list, zip(*map(fkeys, left_keys, right_keys)))
#    1305
#    1306     # get flat i8 keys from label lists
#
# ~\Anaconda3\envs\park_env\lib\site-packages\pandas\core\reshape\merge.py in _factorize_keys(lk, rk, sort)
#    1900     rizer = klass(max(len(lk), len(rk)))
#    1901
# -> 1902     llab = rizer.factorize(lk)
#    1903     rlab = rizer.factorize(rk)
#    1904
#
# pandas\_libs\hashtable.pyx in pandas._libs.hashtable.Factorizer.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'Polygon'

# %%
access_race_final.columns

# %%
access_race_final.head()

# %%
access_racetable.head()

# %% [markdown]
# ### Run spatial analysis on the amount of people distributed within a census block group against the quarter mile park buffer area and the income census data

# %%
ip_intersection = gpd.overlay(income, quartbuff, how='intersection') #https://geopandas.org/set_operations.html
ip_intersection['iarea_intersec'] = ip_intersection['geometry'].area
ip_intersection.to_file(wd+"data/access/ip_intersec_quarterbuff_ACS17.shp")
ip_intersection

# %%
ip_intersection.columns

# %%
ip_intersection[['GEOID10','Total_POP','fullarea_income','LOCATION_N','fullarea_buff','iarea_intersec','geometry']]

# %%
income_clip=ip_intersection.copy().reset_index()

for val in income_clip:

    income_clip['weight'] = income_clip['iarea_intersec']/ income_clip['fullarea_income']
    
    income_clip['access_by_income_TotalPop'] = income_clip['weight'] * income_clip['Total_POP']
    
    income_clip['Less than $25,000'] = (income_clip['weight'] * income_clip['Less than $10,000'])\
                                        +(income_clip['weight'] * income_clip['$10,000 to $14,999'])\
                                        +(income_clip['weight'] * income_clip['$15,000 to $19,999'])\
                                        +(income_clip['weight'] * income_clip['$20,000 to $24,999'])
    
    income_clip['$25,000 to $49,999'] = (income_clip['weight'] * income_clip['$25,000 to $29,999'])\
                                        +(income_clip['weight'] * income_clip['$30,000 to $34,999'])\
                                        +(income_clip['weight'] * income_clip['$35,000 to $39,999'])\
                                        +(income_clip['weight'] * income_clip['$40,000 to $44,999'])\
                                        +(income_clip['weight'] * income_clip['$45,000 to $49,999'])\
    
    income_clip['$50,000 to $74,999'] = (income_clip['weight'] * income_clip['$50,000 to $59,999'])\
                                        +(income_clip['weight'] * income_clip['$60,000 to $74,999'])\
    
    income_clip['$75,000 to $99,999'] = (income_clip['weight'] * income_clip['$75,000 to $99,999'])
    
    income_clip['$100,000 to $149,999'] = (income_clip['weight'] * income_clip['$100,000 to $124,999'])\
                                            +(income_clip['weight'] * income_clip['$125,000 to $149,999'])\
    
    income_clip['$150,000 or more'] = (income_clip['weight'] * income_clip['$150,000 to $199,999'])\
                                        +(income_clip['weight'] * income_clip['$200,000 or more'])\
    
income_clip.head()

# %%
income_clip.columns

# %%
income_calc = income_clip[['LOCATION_N', 'access_by_income_TotalPop', 'Less than $25,000','$25,000 to $49,999',\
                           '$50,000 to $74,999','$75,000 to $99,999','$100,000 to $149,999','$150,000 or more','geometry']]

income_access_data = income_calc.dissolve(by='LOCATION_N', aggfunc='sum')
income_access_data.to_file(wd+"data/access/access_data_income_ACS17.shp")
income_access_data

# %%
df = pd.DataFrame(access_data)
df['Total_Pop'] = df['access_pop'].astype(int)
df['Non_Hispan'] = df['access_nonhis'].astype(int)
df['White'] = df['access_white'].astype(int)
df['Hispan_Latin'] = df['access_his_lat'].astype(int)
df.drop(columns=['geometry'])

df.read_csv(wd+"data/censustables/access_datatable_race_ACS17.csv")
df.head(10)

# %% [markdown]
# ### END OF CODE

# %% [raw]
# parkspop = df.copy()
# quartbuff = gpd.read_file(wd+"data/coaparks_buffer/quarterbuffgj.geojson")
# qbuff = quartbuff.copy()
# parksnocem= qbuff.loc[~qbuff['LOCATION_N'].str.contains('Cemetery')].reset_index()
# parks_pop = parksnocem.merge(parkspop, left_on='LOCATION_N', right_on='Park_Name', suffixes=('_parksnocem', '_parkspop'))
# parks_pop.to_file(wd+"data/access/parks_pop_quarterbuff_ACS17.shp")

# %% [raw]
# data = {'Park_Name':[],
#        'Calc_Pop':[]}
#
# from shapely.geometry import Polygon
# names = quartbuff['LOCATION_N'].unique()
# for i, dfrow in parks.iterrows():
#      name = dfrow['LOCATION_N']
#
# for i,name in enumerate(names):
#     park = quartbuff.loc[quartbuff['LOCATION_N'] == name]
#     park['geometry'] = park['geometry'].buffer(0) #This is the buffer
# #     print(i, name)
#
#     is_in_park = False
#     for j, dfrow in pop.iterrows(): # iterate over pop shapes
# #         print(dfrow['geometry'].is_valid)
#         for n, dfrow2 in park.iterrows(): # iterate over buffered park shape
#             # check if any pop shps fall within the buffered park shapes
#             if Polygon(dfrow['geometry']).intersects(Polygon(dfrow2['geometry'])):
#                 is_in_park = True
#                 break
#     if is_in_park:
#         pop_valid = pop.copy()
#         pop_valid['geometry'] = pop_valid['geometry'].buffer(0) # fix invalid polygons by buffering them by zero distances
#         # definetly a hack and should be looked into.
#         pop_clip = clip_shp(pop_valid,park)
#
#         pop_clip['new_area'] = pop_clip['geometry'].area
#         pop_clip['weight'] = pop_clip['new_area']/ pop_clip['full_area']
#         pop_clip['new_pop'] = pop_clip['weight'] * pop_clip['Estimate;']
#
#         data['Park_Name'].append(name)
#         data['Calc_Pop'].append(pop_clip['new_pop'].sum())
#     else: # if no pop blocks are within the park then return 0
#         data['Park_Name'].append(name)
#         data['Calc_Pop'].append(0)
#
# # print(park.head())

# %% [raw]
# data = {'LOCATION_N':[],'access_pop':[],'access_nonhis':[],'access_white':[],'access_his_lat':[]}
#
# #data['Park_Name'].append(name)
# data['access_pop'].append(access_data['access_pop'])
# data['access_nonhis'].append(access_data['access_nonhis'])
# data['White'].append(access_data['access_white'])
# data['Hispan_Latin'].append(access_data['access_his_lat'])

# %% [raw]
# fig, ax = plt.subplots(figsize=(12,12))
# base = rp_intersection.plot(ax=ax, color="black", alpha=0.2)
# layer = rp_intersection["geometry"].plot(ax=base, color='black', edgecolor = 'black')
