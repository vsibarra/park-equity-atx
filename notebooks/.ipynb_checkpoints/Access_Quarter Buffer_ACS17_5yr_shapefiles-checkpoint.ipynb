# %%
import geopandas as gpd
import pandas as pd
import os
import getpass
import matplotlib.pyplot as plt

# %% [markdown]
# ### NOTES:

# %% [markdown]
# ###### Bring in necessary geojson files and set your projection for all files

# %%
wd = os.getcwd()
wd = wd[:wd.find('notebooks')]

#crs is set for Central Texas; https://epsg.io/6578; 
crs =  {'init' :'epsg:6578'}

parks = gpd.read_file(wd+"data/coaparks/parkboundaries.geojson")
parks = parks.to_crs(crs).explode().reset_index()

quartbuff = gpd.read_file(wd+"data/coaparks_buffer/quarterbuff.shp")
quartbuff.crs={'init' :'epsg:6578'}

pop = gpd.read_file(wd+"data/blockgroups_censusdata/popmerge.shp")
pop = pop.to_crs(crs).reset_index()

race = gpd.read_file(wd+"data/blockgroups_censusdata/racemerge.shp")
race = race.to_crs(crs).reset_index()

income = gpd.read_file(wd+"data/blockgroups_censusdata/incomemerge.shp")
income = income.to_crs(crs).reset_index()

age = gpd.read_file(wd+"data/blockgroups_censusdata/agemerge.shp")
age = age.to_crs(crs).reset_index()

# %% [markdown]
# ##### Check your projections
# https://geopandas.org/projections.html

# %%
#quartbuff.crs

# %%
#pop.crs

# %%
#race.crs

# %%
#age.crs

# %% [markdown]
# ###### Preview the files and clean the data

# %%
pop['fullarea_pop'] = pop['geometry'].area
#pop.head()

# %%
race['fullarea_race'] = race['geometry'].area
#race.head()

# %%
income['fullarea_income'] = income['geometry'].area
#income.head()

# %%
age['fullarea_age'] = age['geometry'].area
#age.head()

# %%
quartbuff['fullarea_buff'] = quartbuff['geometry'].area
#quartbuff.head()

# %% [markdown]
# ##### The three cells below give totals for each demographic group. These will be used at the end to compare the total amount of the population as compared to the number served.

# %%
#race.sum( axis = 0,skipna = True,numeric_only=True)

# %%
#income.sum( axis = 0,skipna = True,numeric_only=True)

# %%
#age.sum( axis = 0,skipna = True,numeric_only=True)

# %%
park_dif = parks.copy()
qbuff = quartbuff.copy()
race_dif = race.copy()
income_dif = income.copy()
age_dif = age.copy()

# %%
race_difference = gpd.overlay(race_dif, park_dif, how='difference')
income_difference = gpd.overlay(income_dif, park_dif, how='difference')
age_difference = gpd.overlay(age_dif, park_dif, how='difference')

# %%
race_difference = gpd.overlay(race_difference, qbuff, how='difference')
income_difference = gpd.overlay(income_difference, qbuff, how='difference')
age_difference = gpd.overlay(age_difference, qbuff, how='difference')

# %%
fig, ax = plt.subplots(figsize=(10,10))
race_difference.plot(ax = ax, color='grey');

# %%
race_difference['Total_POP']
# Out:
# 0      2205
# 1      3774
# 2      1045
# 3      1202
# 4      2016
#        ...
# 553    1264
# 554    2504
# 555    3192
# 556    4695
# 557     929
# Name: Total_POP, Length: 556, dtype: int64

# %%
race_difference.columns
# Out:
# Index(['level_0', 'index', 'GEOID10', 'ALAND10', 'AWATER10', 'area_ft',
#        'area_acres', 'jurisdic_3', 'modified_f', 'objectid', 'shape_area',
#        'shape_leng', 'Id', 'Id2', 'Total_POP', 'Not Hispan', 'White; Not',
#        'Black or A', 'American I', 'Asian; Not', 'Native Haw', 'Some other',
#        'Two or mor', 'Hispanic o', 'Sum of Non', 'area_inter', 'weight',
#        'Total_POP_', 'Not Hisp_1', 'White; N_1', 'Hispanic_1', 'geometry',
#        'fullarea_race'],
#       dtype='object')

# %%
race_ns = race_difference[[ 'GEOID10','Total_POP_', 'Not Hisp_1', 'White; N_1', 'Hispanic_1','area_inter','geometry']]

# %%
race.head()
# Out:
#    level_0  index       GEOID10     ALAND10  AWATER10       area_ft  \
# 0        0      0  482090109011  14489039.0       0.0  1.559551e+08
# 1        1      1  482090109081    171531.0       0.0  1.846354e+06
# 2        2      2  484530001011    950911.0       0.0  1.023445e+07
# 3        3      3  484530001012   1106260.0       0.0  1.190644e+07
# 4        4      4  484530001013   1069511.0       0.0  1.151098e+07
#
#    area_acres  jurisdic_3  modified_f  objectid  ...  Hispanic o  Sum of Non  \
# 0    3580.237       306.0      1890.0     990.0  ...         421        2205
# 1      42.386        68.0       420.0     220.0  ...        2507        3774
# 2     234.950       510.0      3150.0    1650.0  ...         113        1045
# 3     273.332      1224.0      7560.0    3960.0  ...         121        1202
# 4     264.255      1054.0      6510.0    3410.0  ...         163        2016
#
#      area_inter    weight  Total_POP_  Not Hisp_1  White; N_1  Hispanic_1  \
# 0  2.280497e+07  0.146228         322         260         238          61
# 1  1.837684e+03  0.000995           3           1           1           2
# 2  1.023445e+07  1.000000        1045         932         886         113
# 3  1.190644e+07  1.000000        1202        1081        1025         121
# 4  1.151098e+07  1.000000        2015        1852        1743         162
#
#                                             geometry  fullarea_race
# 0  (POLYGON ((3069238.317597141 10028016.9612432,...   2.280497e+07
# 1  POLYGON ((3093548.488136804 10008631.07120929,...   1.837684e+03
# 2  POLYGON ((3111310.380106392 10089474.08471978,...   1.023445e+07
# 3  POLYGON ((3109356.370562974 10091521.99532213,...   1.190644e+07
# 4  POLYGON ((3110878.498096142 10085236.13059729,...   1.151098e+07
#
# [5 rows x 33 columns]

# %%
race_ns.head()
# Out:
#         GEOID10  Total_POP_  Not Hisp_1  White; N_1  Hispanic_1    area_inter  \
# 0  482090109011         322         260         238          61  2.280497e+07
# 1  482090109081           3           1           1           2  1.837684e+03
# 2  484530001011        1045         932         886         113  1.023445e+07
# 3  484530001012        1202        1081        1025         121  1.190644e+07
# 4  484530001013        2015        1852        1743         162  1.151098e+07
#
#                                             geometry
# 0  (POLYGON ((3069238.317597141 10028016.9612432,...
# 1  POLYGON ((3093548.488136804 10008631.07120929,...
# 2  (POLYGON ((3113067.140044288 10090155.08991955...
# 3  (POLYGON ((3109356.370562974 10091521.99532213...
# 4  (POLYGON ((3112409.740112369 10084643.51990589...

# %%
race_ns['new_area'] = race_ns['geometry'].area
race_ns['area_acre'] = (race_ns['new_area']/43560)
# Out:
# C:\Users\Victoria\Anaconda3\envs\park_env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Victoria\Anaconda3\envs\park_env\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
race_ns.columns
# Out:
# Index(['GEOID10', 'Total_POP_', 'Not Hisp_1', 'White; N_1', 'Hispanic_1',
#        'area_inter', 'geometry', 'new_area', 'area_acre'],
#       dtype='object')

# %%
# for val in race_ns:

#     race_ns['weight'] = race_ns['new_area']/ race_ns['area_inter']
    
#     race_ns['TotPopNS'] = (race_ns['weight'] * race_ns['Total_POP_']).astype(int)
#     race_ns['NotHisNS'] = (race_ns['weight'] * race_ns['Not Hisp_1']).astype(int)
#     race_ns['WhiteNS'] = (race_ns['weight'] * race_ns['White; N_1']).astype(int)
#     race_ns['HispanNS'] = (race_ns['weight'] * race_ns['Hispanic_1']).astype(int)

race_ns.columns
# Out:
# Index(['GEOID10', 'Total_POP_', 'Not Hisp_1', 'White; N_1', 'Hispanic_1',
#        'area_inter', 'geometry', 'new_area', 'area_acre', 'weight', 'TotPopNS',
#        'NotHisNS', 'WhiteNS', 'HispanNS'],
#       dtype='object')

# %%
race_ns['Norm_byArea'] = race_ns['TotPopNS']/race_ns['area_acre']
race_ns['Norm_nonhis'] = race_ns['NotHisNS']/race_ns['area_acre']
race_ns['Norm_white'] = race_ns['WhiteNS']/race_ns['area_acre']
race_ns['Norm_hislat'] = race_ns['HispanNS']/race_ns['area_acre']

.to_file(wd+"data/access/.shp")
race_ns.head()
# Out:
# C:\Users\Victoria\Anaconda3\envs\park_env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Victoria\Anaconda3\envs\park_env\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Victoria\Anaconda3\envs\park_env\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Victoria\Anaconda3\envs\park_env\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#         GEOID10  Total_POP_  Not Hisp_1  White; N_1  Hispanic_1    area_inter  \
# 0  482090109011         322         260         238          61  2.280497e+07
# 1  482090109081           3           1           1           2  1.837684e+03
# 2  484530001011        1045         932         886         113  1.023445e+07
# 3  484530001012        1202        1081        1025         121  1.190644e+07
# 4  484530001013        2015        1852        1743         162  1.151098e+07
#
#                                             geometry      new_area  \
# 0  (POLYGON ((3069238.317597141 10028016.9612432,...  2.280497e+07
# 1  POLYGON ((3093548.488136804 10008631.07120929,...  1.837684e+03
# 2  (POLYGON ((3113067.140044288 10090155.08991955...  1.808925e+05
# 3  (POLYGON ((3109356.370562974 10091521.99532213...  6.324010e+06
# 4  (POLYGON ((3112409.740112369 10084643.51990589...  4.683157e+06
#
#     area_acre    weight  TotPopNS  NotHisNS  WhiteNS  HispanNS  Norm_byArea  \
# 0  523.529986  1.000000       322       260      238        61     0.615056
# 1    0.042187  1.000000         3         1        1         2    71.111248
# 2    4.152719  0.017675        18        16       15         1     4.334509
# 3  145.179288  0.531142       638       574      544        64     4.394566
# 4  107.510497  0.406842       819       753      709        65     7.617861
#
#    Norm_nonhis  Norm_white  Norm_hislat
# 0     0.496629    0.454606     0.116517
# 1    23.703749   23.703749    47.407499
# 2     3.852897    3.612091     0.240806
# 3     3.953732    3.747091     0.440834
# 4     7.003967    6.594705     0.604592

# %% [markdown]
# ### <font color=green>Run spatial analysis on the amount of people distributed within a census block group against the quarter mile park buffer area and the race census data</font>

# %%
rp_intersection = gpd.overlay(race, quartbuff, how='intersection') #https://geopandas.org/set_operations.html
rp_intersection['area_intersec'] = rp_intersection['geometry'].area
rp_intersection.to_file(wd+"data/access/rp_intersec_quarterbuff_ACS17.shp")
rp_intersection.head()
# Out:
#       level_0  index       GEOID10    ALAND10  AWATER10       area_ft  \
# 2           2      2  484530001011   950911.0       0.0  1.023445e+07
# 4           3      3  484530001012  1106260.0       0.0  1.190644e+07
# 8           4      4  484530001013  1069511.0       0.0  1.151098e+07
# 34          8      8  484530002041   514123.0       0.0  5.533474e+06
# 37          9      9  484530002042   551614.0       0.0  5.936942e+06
# ...       ...    ...           ...        ...       ...           ...
# 2196      542    542  484910204083   298417.0       0.0  3.211641e+06
# 2198      544    544  484910204092  1185181.0       0.0  1.275526e+07
# 2201      552    552  484910205081  4018118.0    2409.0  4.326969e+07
# 2206      556    556  484910205101  4745633.0    1268.0  5.108690e+07
# 2208      557    557  484910205103   346320.0       0.0  3.727163e+06
#
#       area_acres  jurisdic_3  modified_f  objectid  ...  GLOBALID  \
# 2        234.950       510.0      3150.0    1650.0  ...      None
# 4        273.332      1224.0      7560.0    3960.0  ...      None
# 8        264.255      1054.0      6510.0    3410.0  ...      None
# 34       127.033      1088.0      6720.0    3520.0  ...      None
# 37       136.293       816.0      5040.0    2640.0  ...      None
# ...          ...         ...         ...       ...  ...       ...
# 2196      73.729       170.0      1050.0     550.0  ...      None
# 2198     292.821       884.0      5460.0    2860.0  ...      None
# 2201     993.336       340.0      2100.0    1100.0  ...      None
# 2206    1172.794      1190.0      7350.0    3850.0  ...      None
# 2208      85.565       340.0      2100.0    1100.0  ...      None
#
#          CREATED_BY  CREATED_DA     MODIFIED_B  MODIFIED_D    Shape__Are  \
# 2     CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 4     CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 8     CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 34    CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 37    CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# ...             ...         ...            ...         ...           ...
# 2196  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  5.423833e+05
# 2198  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  5.423833e+05
# 2201  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05
# 2206  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05
# 2208  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05
#
#         Shape__Len  fullarea_buff  \
# 2     56641.286637   7.685576e+07
# 4     56641.286637   7.685576e+07
# 8     56641.286637   7.685576e+07
# 34    56641.286637   7.685576e+07
# 37    56641.286637   7.685576e+07
# ...            ...            ...
# 2196   2970.882179   9.386213e+06
# 2198   2970.882179   9.386213e+06
# 2201   3819.975953   1.025997e+07
# 2206   3819.975953   1.025997e+07
# 2208   3819.975953   1.025997e+07
#
#                                                geometry  area_intersec
# 2     (POLYGON ((3111310.380106392 10089474.08471978...   7.977811e+06
# 4     (POLYGON ((3110963.100224382 10092814.33601546...   3.558330e+05
# 8     POLYGON ((3110878.498096142 10085236.13059729,...   6.430365e+06
# 34    POLYGON ((3114161.352732578 10080856.88449187,...   2.730844e+06
# 37    (POLYGON ((3113607.519823685 10085639.98593919...   3.749049e+06
# ...                                                 ...            ...
# 2196  POLYGON ((3099402.330431718 10136725.68772296,...   6.554068e+05
# 2198  POLYGON ((3102295.150253439 10137882.6017911, ...   6.260890e+03
# 2201  POLYGON ((3103070.9294554 10151562.85760724, 3...   4.403025e+06
# 2206  (POLYGON ((3105356.685648966 10148942.41788262...   4.356998e+06
# 2208  POLYGON ((3104338.228040222 10151913.94934112,...   1.499946e+06
#
# [1420 rows x 88 columns]

# %%
#rp_intersection.crs

# %%
rp_intersection.columns
# Out:
# Index(['level_0', 'index', 'GEOID10', 'ALAND10', 'AWATER10', 'area_ft',
#        'area_acres', 'jurisdic_3', 'modified_f', 'objectid', 'shape_area',
#        'shape_leng', 'Id', 'Id2', 'Total_POP', 'Not Hispan', 'White; Not',
#        'Black or A', 'American I', 'Asian; Not', 'Native Haw', 'Some other',
#        'Two or mor', 'Hispanic o', 'Sum of Non', 'area_inter', 'weight',
#        'Total_POP_', 'Not Hisp_1', 'White; N_1', 'Hispanic_1', 'fullarea_race',
#        'ASSET_MGMT', 'LOCATION_N', 'ADDRESS', 'CITY_MUNIC', 'COUNTY', 'STATE',
#        'STREET_NUM', 'STREET_NAM', 'STREET_TYP', 'ZIPCODE', 'ASSET_SIZE',
#        'ACRE_SOURC', 'UNIT_OF_ME', 'YEAR_ACQUI', 'ASSET_STAT', 'DEVELOPMEN',
#        'TPL_LANDUS', 'PARK_TYPE', 'LEVEL_OF_S', 'LEVEL_OF_U', 'SERVICE_AR',
#        'COUNCIL_DI', 'COUNCIL__1', 'MANAGEMENT', 'OWNER_NAME', 'OWNER_TYPE',
#        'MANAGING_N', 'MANAGING_T', 'ACQUISITIO', 'ACQUISIT_1', 'ACQUISIT_2',
#        'DEVELOPM_1', 'DEVELOPM_2', 'RESTRICTIO', 'LWCF_PROTE', 'OTHER_PROT',
#        'REST_PROT_', 'COMMUNITY_', 'MXASSETNUM', 'MXLOCATION', 'MXSITEID',
#        'MXCREATION', 'MXSTATUS', 'MXCONDITIO', 'MXPRIORITY', 'MXLOADID',
#        'GLOBALID', 'CREATED_BY', 'CREATED_DA', 'MODIFIED_B', 'MODIFIED_D',
#        'Shape__Are', 'Shape__Len', 'fullarea_buff', 'geometry',
#        'area_intersec'],
#       dtype='object')

# %%
rp_intersection[['GEOID10','Total_POP_','fullarea_race','LOCATION_N','fullarea_buff','area_intersec','geometry']]
# Out:
#            GEOID10  Total_POP_  fullarea_race                     LOCATION_N  \
# 2     484530001011        1045   1.023445e+07          Shoal Creek Greenbelt
# 4     484530001012        1202   1.190644e+07          Shoal Creek Greenbelt
# 8     484530001013        2015   1.151098e+07          Shoal Creek Greenbelt
# 34    484530002041        1112   5.533474e+06          Shoal Creek Greenbelt
# 37    484530002042        1254   5.936942e+06          Shoal Creek Greenbelt
# ...            ...         ...            ...                            ...
# 2196  484910204083         246   9.487768e+05  Springwoods Neighborhood Park
# 2198  484910204092        2109   1.085400e+07  Springwoods Neighborhood Park
# 2201  484910205081        3212   3.682212e+07      Davis Spring Special Park
# 2206  484910205101        3181   3.462268e+07      Davis Spring Special Park
# 2208  484910205103         928   3.727163e+06      Davis Spring Special Park
#
#       fullarea_buff  area_intersec  \
# 2      7.685576e+07   7.977811e+06
# 4      7.685576e+07   3.558330e+05
# 8      7.685576e+07   6.430365e+06
# 34     7.685576e+07   2.730844e+06
# 37     7.685576e+07   3.749049e+06
# ...             ...            ...
# 2196   9.386213e+06   6.554068e+05
# 2198   9.386213e+06   6.260890e+03
# 2201   1.025997e+07   4.403025e+06
# 2206   1.025997e+07   4.356998e+06
# 2208   1.025997e+07   1.499946e+06
#
#                                                geometry
# 2     (POLYGON ((3111310.380106392 10089474.08471978...
# 4     (POLYGON ((3110963.100224382 10092814.33601546...
# 8     POLYGON ((3110878.498096142 10085236.13059729,...
# 34    POLYGON ((3114161.352732578 10080856.88449187,...
# 37    (POLYGON ((3113607.519823685 10085639.98593919...
# ...                                                 ...
# 2196  POLYGON ((3099402.330431718 10136725.68772296,...
# 2198  POLYGON ((3102295.150253439 10137882.6017911, ...
# 2201  POLYGON ((3103070.9294554 10151562.85760724, 3...
# 2206  (POLYGON ((3105356.685648966 10148942.41788262...
# 2208  POLYGON ((3104338.228040222 10151913.94934112,...
#
# [1420 rows x 7 columns]

# %%
race_clip=rp_intersection.copy()

for val in race_clip:

    race_clip['weight'] = race_clip['area_intersec']/ race_clip['fullarea_race']
    
    race_clip['access_pop'] = race_clip['weight'] * race_clip['Total_POP_']
    race_clip['access_nonhis'] = race_clip['weight'] * race_clip['Not Hispan']
    race_clip['access_white'] = race_clip['weight'] * race_clip['White; Not']
    race_clip['access_his_lat'] = race_clip['weight'] * race_clip['Hispanic o']

race_clip.head()
# Out:
#     level_0  index       GEOID10    ALAND10  AWATER10       area_ft  \
# 2         2      2  484530001011   950911.0       0.0  1.023445e+07
# 4         3      3  484530001012  1106260.0       0.0  1.190644e+07
# 8         4      4  484530001013  1069511.0       0.0  1.151098e+07
# 34        8      8  484530002041   514123.0       0.0  5.533474e+06
# 37        9      9  484530002042   551614.0       0.0  5.936942e+06
#
#     area_acres  jurisdic_3  modified_f  objectid  ...  MODIFIED_D  \
# 2      234.950       510.0      3150.0    1650.0  ...  2019-10-12
# 4      273.332      1224.0      7560.0    3960.0  ...  2019-10-12
# 8      264.255      1054.0      6510.0    3410.0  ...  2019-10-12
# 34     127.033      1088.0      6720.0    3520.0  ...  2019-10-12
# 37     136.293       816.0      5040.0    2640.0  ...  2019-10-12
#
#       Shape__Are    Shape__Len fullarea_buff  \
# 2   3.514350e+06  56641.286637  7.685576e+07
# 4   3.514350e+06  56641.286637  7.685576e+07
# 8   3.514350e+06  56641.286637  7.685576e+07
# 34  3.514350e+06  56641.286637  7.685576e+07
# 37  3.514350e+06  56641.286637  7.685576e+07
#
#                                              geometry  area_intersec  \
# 2   (POLYGON ((3111310.380106392 10089474.08471978...   7.977811e+06
# 4   (POLYGON ((3110963.100224382 10092814.33601546...   3.558330e+05
# 8   POLYGON ((3110878.498096142 10085236.13059729,...   6.430365e+06
# 34  POLYGON ((3114161.352732578 10080856.88449187,...   2.730844e+06
# 37  (POLYGON ((3113607.519823685 10085639.98593919...   3.749049e+06
#
#      access_pop  access_nonhis  access_white  access_his_lat
# 2    814.583701     726.499531    690.642258       88.084171
# 4     35.922669      32.306493     30.632891        3.616175
# 8   1125.636590    1035.138760    974.248245       91.056459
# 34   548.786903     471.305299    399.252342       77.975118
# 37   791.873571     695.888896    632.109605       96.616153
#
# [5 rows x 92 columns]

# %%
#race_clip.columns

# %%
race_calc = race_clip[['LOCATION_N', 'Total_POP_','access_pop', 'access_nonhis','access_white', 'access_his_lat','area_intersec','geometry']]
access_data = race_calc.dissolve(by='LOCATION_N',as_index=False, aggfunc='sum')

# %%
access_data
# Out:
#                            LOCATION_N  \
# 0      A.B. Dittmar Neighborhood Park
# 1    Adams-Hemphill Neighborhood Park
# 2             Agave Neighborhood Park
# 3                   Alamo Pocket Park
# 4              Alderbrook Pocket Park
# ..                                ...
# 267          Wooten Neighborhood Park
# 268     Wunneburger Neighborhood Park
# 269                 Yates Pocket Park
# 270      Yett Creek Neighborhood Park
# 271                 Zilker Metro Park
#
#                                               geometry  Total_POP_  \
# 0    POLYGON ((3097945.260486613 10040357.04514253,...        6626
# 1    POLYGON ((3116425.666618853 10079471.33829271,...       21042
# 2    (POLYGON ((3145065.384555357 10081869.95696411...        6157
# 3    POLYGON ((3122655.295172911 10075520.37048018,...        6557
# 4    POLYGON ((3128917.516225351 10124262.76067684,...        5329
# ..                                                 ...         ...
# 267  POLYGON ((3121269.433041437 10100828.585948, 3...        7926
# 268  (POLYGON ((3095156.226719216 10021252.69393206...        3024
# 269  POLYGON ((3128555.312776149 10058188.62391765,...        8794
# 270  POLYGON ((3117329.523365858 10127115.06004296,...        4787
# 271  (POLYGON ((3105774.874722705 10073559.67186339...       14579
#
#       access_pop  access_nonhis  access_white  access_his_lat  area_intersec
# 0    1273.144971     865.679107    711.176368      407.719306   8.989080e+06
# 1    6559.199112    5540.140840   4071.105492     1021.355082   1.210141e+07
# 2    1599.033656     265.761114    152.212052     1339.556558   1.068866e+07
# 3    1125.732090    1002.439231    736.495784      123.540364   6.974684e+06
# 4    2303.375334    1707.181710   1362.143073      597.158742   7.023673e+06
# ..           ...            ...           ...             ...            ...
# 267  1980.351381     949.190244    782.338856     1031.247824   8.291559e+06
# 268    58.504021      58.291209     49.585254       37.551688   6.028135e+05
# 269  1380.651306     576.955867    173.649796      803.745633   5.434093e+06
# 270   873.435735     813.059407    744.951304       98.806014   1.243347e+07
# 271  2536.533047    2323.055885   2040.005637      221.521884   1.630279e+07
#
# [272 rows x 8 columns]

# %% [markdown]
# ##### Combine the park area data to the access data

# %%
parks_ = quartbuff[['LOCATION_N','ASSET_SIZE']].copy()

# %%
parks_
# Out:
#                               LOCATION_N  ASSET_SIZE
# 0           Stratford Overlook Greenbelt     0.07000
# 1             Highland Neighborhood Park     0.24100
# 2                Palma Plaza Pocket Park     0.20660
# 3               Oertli Neighborhood Park     6.00000
# 4    Peace Point at Town Lake Metro Park     5.46669
# ..                                   ...         ...
# 273  South Austin Senior Activity Center     4.63000
# 274          Red Bluff Neighborhood Park     7.19600
# 275        MLK Station Neighborhood Park     7.91700
# 276               Garrison District Park    40.00000
# 277            Davis Spring Special Park    14.47200
#
# [278 rows x 2 columns]

# %%
access_data = access_data.merge(parks_, on='LOCATION_N')

# %%
access_data
# Out:
#                            LOCATION_N  \
# 0      A.B. Dittmar Neighborhood Park
# 1    Adams-Hemphill Neighborhood Park
# 2             Agave Neighborhood Park
# 3                   Alamo Pocket Park
# 4              Alderbrook Pocket Park
# ..                                ...
# 268          Wooten Neighborhood Park
# 269     Wunneburger Neighborhood Park
# 270                 Yates Pocket Park
# 271      Yett Creek Neighborhood Park
# 272                 Zilker Metro Park
#
#                                               geometry  Total_POP_  \
# 0    POLYGON ((3097945.260486613 10040357.04514253,...        6626
# 1    POLYGON ((3116425.666618853 10079471.33829271,...       21042
# 2    (POLYGON ((3145065.384555357 10081869.95696411...        6157
# 3    POLYGON ((3122655.295172911 10075520.37048018,...        6557
# 4    POLYGON ((3128917.516225351 10124262.76067684,...        5329
# ..                                                 ...         ...
# 268  POLYGON ((3121269.433041437 10100828.585948, 3...        7926
# 269  (POLYGON ((3095156.226719216 10021252.69393206...        3024
# 270  POLYGON ((3128555.312776149 10058188.62391765,...        8794
# 271  POLYGON ((3117329.523365858 10127115.06004296,...        4787
# 272  (POLYGON ((3105774.874722705 10073559.67186339...       14579
#
#       access_pop  access_nonhis  access_white  access_his_lat  area_intersec  \
# 0    1273.144971     865.679107    711.176368      407.719306   8.989080e+06
# 1    6559.199112    5540.140840   4071.105492     1021.355082   1.210141e+07
# 2    1599.033656     265.761114    152.212052     1339.556558   1.068866e+07
# 3    1125.732090    1002.439231    736.495784      123.540364   6.974684e+06
# 4    2303.375334    1707.181710   1362.143073      597.158742   7.023673e+06
# ..           ...            ...           ...             ...            ...
# 268  1980.351381     949.190244    782.338856     1031.247824   8.291559e+06
# 269    58.504021      58.291209     49.585254       37.551688   6.028135e+05
# 270  1380.651306     576.955867    173.649796      803.745633   5.434093e+06
# 271   873.435735     813.059407    744.951304       98.806014   1.243347e+07
# 272  2536.533047    2323.055885   2040.005637      221.521884   1.630279e+07
#
#      ASSET_SIZE
# 0     12.690000
# 1      9.310000
# 2     16.360000
# 3      1.820000
# 4      1.900000
# ..          ...
# 268    6.280000
# 269   23.510000
# 270    0.933800
# 271   40.545000
# 272  307.849066
#
# [273 rows x 9 columns]

# %% [markdown]
# ##### The population served by parks is nomalized by dividing the population served by the area of the park for which they are being served

# %%
access_data['Normalized_byArea'] = access_data['access_pop']/access_data['ASSET_SIZE']
access_data['Normalized_nonhis'] = access_data['access_nonhis']/access_data['ASSET_SIZE']
access_data['Normalized_white'] = access_data['access_white']/access_data['ASSET_SIZE']
access_data['Normalized_hislat'] = access_data['access_his_lat']/access_data['ASSET_SIZE']

# %%
access_data.to_file(wd+"data/access/access_data_race_quarterbuff_ACS17.shp")
access_data
# Out:
#                            LOCATION_N  \
# 0      A.B. Dittmar Neighborhood Park
# 1    Adams-Hemphill Neighborhood Park
# 2             Agave Neighborhood Park
# 3                   Alamo Pocket Park
# 4              Alderbrook Pocket Park
# ..                                ...
# 268          Wooten Neighborhood Park
# 269     Wunneburger Neighborhood Park
# 270                 Yates Pocket Park
# 271      Yett Creek Neighborhood Park
# 272                 Zilker Metro Park
#
#                                               geometry  Total_POP_  \
# 0    POLYGON ((3097945.260486613 10040357.04514253,...        6626
# 1    POLYGON ((3116425.666618853 10079471.33829271,...       21042
# 2    (POLYGON ((3145065.384555357 10081869.95696411...        6157
# 3    POLYGON ((3122655.295172911 10075520.37048018,...        6557
# 4    POLYGON ((3128917.516225351 10124262.76067684,...        5329
# ..                                                 ...         ...
# 268  POLYGON ((3121269.433041437 10100828.585948, 3...        7926
# 269  (POLYGON ((3095156.226719216 10021252.69393206...        3024
# 270  POLYGON ((3128555.312776149 10058188.62391765,...        8794
# 271  POLYGON ((3117329.523365858 10127115.06004296,...        4787
# 272  (POLYGON ((3105774.874722705 10073559.67186339...       14579
#
#       access_pop  access_nonhis  access_white  access_his_lat  area_intersec  \
# 0    1273.144971     865.679107    711.176368      407.719306   8.989080e+06
# 1    6559.199112    5540.140840   4071.105492     1021.355082   1.210141e+07
# 2    1599.033656     265.761114    152.212052     1339.556558   1.068866e+07
# 3    1125.732090    1002.439231    736.495784      123.540364   6.974684e+06
# 4    2303.375334    1707.181710   1362.143073      597.158742   7.023673e+06
# ..           ...            ...           ...             ...            ...
# 268  1980.351381     949.190244    782.338856     1031.247824   8.291559e+06
# 269    58.504021      58.291209     49.585254       37.551688   6.028135e+05
# 270  1380.651306     576.955867    173.649796      803.745633   5.434093e+06
# 271   873.435735     813.059407    744.951304       98.806014   1.243347e+07
# 272  2536.533047    2323.055885   2040.005637      221.521884   1.630279e+07
#
#      ASSET_SIZE  Normalized_byArea  Normalized_nonhis  Normalized_white  \
# 0     12.690000         100.326633          68.217424         56.042267
# 1      9.310000         704.532665         595.074204        437.283082
# 2     16.360000          97.740444          16.244567          9.303915
# 3      1.820000         618.534115         550.790787        404.668013
# 4      1.900000        1212.302807         898.516689        716.917407
# ..          ...                ...                ...               ...
# 268    6.280000         315.342577         151.144943        124.576251
# 269   23.510000           2.488474           2.479422          2.109113
# 270    0.933800        1478.529991         617.858072        185.960373
# 271   40.545000          21.542378          20.053260         18.373444
# 272  307.849066           8.239535           7.546087          6.626642
#
#      Normalized_hislat
# 0            32.129181
# 1           109.705165
# 2            81.879985
# 3            67.879321
# 4           314.294075
# ..                 ...
# 268         164.211437
# 269           1.597264
# 270         860.725672
# 271           2.436947
# 272           0.719580
#
# [273 rows x 13 columns]

# %% [markdown]
# #### A dataframe is created with the 'acess_data' geoshapefile. This dataframe is cleaned up and the values are convereted into integers. Finally, we export the dataframe into a csv file and a shapefile.

# %%
df = pd.DataFrame(access_data)

df['Park_Name']=df['LOCATION_N']
df['Total_Pop_Served'] = df['access_pop'].astype(int)
df['Normalized_byArea'] = df['Normalized_byArea'].astype(int)
df['Non_Hispan'] = df['access_nonhis'].astype(int)
df['Normalized_nonhis'] = df['Normalized_nonhis'].astype(int)
df['White'] = df['access_white'].astype(int)
df['Normalized_white'] = df['Normalized_white'].astype(int)
df['Hispan_Latin'] = df['access_his_lat'].astype(int)
df['Normalized_hislat'] = df['Normalized_hislat'].astype(int)

df.head()
# Out:
#                          LOCATION_N  \
# 0    A.B. Dittmar Neighborhood Park
# 1  Adams-Hemphill Neighborhood Park
# 2           Agave Neighborhood Park
# 3                 Alamo Pocket Park
# 4            Alderbrook Pocket Park
#
#                                             geometry  Total_POP_   access_pop  \
# 0  POLYGON ((3097945.260486613 10040357.04514253,...        6626  1273.144971
# 1  POLYGON ((3116425.666618853 10079471.33829271,...       21042  6559.199112
# 2  (POLYGON ((3145065.384555357 10081869.95696411...        6157  1599.033656
# 3  POLYGON ((3122655.295172911 10075520.37048018,...        6557  1125.732090
# 4  POLYGON ((3128917.516225351 10124262.76067684,...        5329  2303.375334
#
#    access_nonhis  access_white  access_his_lat  area_intersec  ASSET_SIZE  \
# 0     865.679107    711.176368      407.719306   8.989080e+06       12.69
# 1    5540.140840   4071.105492     1021.355082   1.210141e+07        9.31
# 2     265.761114    152.212052     1339.556558   1.068866e+07       16.36
# 3    1002.439231    736.495784      123.540364   6.974684e+06        1.82
# 4    1707.181710   1362.143073      597.158742   7.023673e+06        1.90
#
#    Normalized_byArea  Normalized_nonhis  Normalized_white  Normalized_hislat  \
# 0                100                 68                56                 32
# 1                704                595               437                109
# 2                 97                 16                 9                 81
# 3                618                550               404                 67
# 4               1212                898               716                314
#
#                           Park_Name  Total_Pop_Served  Non_Hispan  White  \
# 0    A.B. Dittmar Neighborhood Park              1273         865    711
# 1  Adams-Hemphill Neighborhood Park              6559        5540   4071
# 2           Agave Neighborhood Park              1599         265    152
# 3                 Alamo Pocket Park              1125        1002    736
# 4            Alderbrook Pocket Park              2303        1707   1362
#
#    Hispan_Latin
# 0           407
# 1          1021
# 2          1339
# 3           123
# 4           597

# %% [markdown]
# Export to Shapefile

# %%
access_race_final = df.copy().drop(columns=['access_pop','access_nonhis','access_white','access_his_lat'])
access_race_final = gpd.GeoDataFrame(access_race_final, geometry='geometry')
access_race_final.to_file(wd+"data/access/access_race_final_quarterbuff_ACS17.shp")
access_race_final.head()
# Out:
#                          LOCATION_N  \
# 0    A.B. Dittmar Neighborhood Park
# 1  Adams-Hemphill Neighborhood Park
# 2           Agave Neighborhood Park
# 3                 Alamo Pocket Park
# 4            Alderbrook Pocket Park
#
#                                             geometry  Total_POP_  \
# 0  POLYGON ((3097945.260486613 10040357.04514253,...        6626
# 1  POLYGON ((3116425.666618853 10079471.33829271,...       21042
# 2  (POLYGON ((3145065.384555357 10081869.95696411...        6157
# 3  POLYGON ((3122655.295172911 10075520.37048018,...        6557
# 4  POLYGON ((3128917.516225351 10124262.76067684,...        5329
#
#    area_intersec  ASSET_SIZE  Normalized_byArea  Normalized_nonhis  \
# 0   8.989080e+06       12.69                100                 68
# 1   1.210141e+07        9.31                704                595
# 2   1.068866e+07       16.36                 97                 16
# 3   6.974684e+06        1.82                618                550
# 4   7.023673e+06        1.90               1212                898
#
#    Normalized_white  Normalized_hislat                         Park_Name  \
# 0                56                 32    A.B. Dittmar Neighborhood Park
# 1               437                109  Adams-Hemphill Neighborhood Park
# 2                 9                 81           Agave Neighborhood Park
# 3               404                 67                 Alamo Pocket Park
# 4               716                314            Alderbrook Pocket Park
#
#    Total_Pop_Served  Non_Hispan  White  Hispan_Latin
# 0              1273         865    711           407
# 1              6559        5540   4071          1021
# 2              1599         265    152          1339
# 3              1125        1002    736           123
# 4              2303        1707   1362           597

# %% [markdown]
# Export to CSV

# %%
access_racetable = df.drop(columns=['access_pop','access_nonhis','access_white','access_his_lat', 'geometry'])
access_racetable.to_csv(wd+"data/access/access_table_race_quarterbuff_ACS17.csv")
access_racetable.head()
# Out:
#                          LOCATION_N  Total_POP_  area_intersec  ASSET_SIZE  \
# 0    A.B. Dittmar Neighborhood Park        6626   8.989080e+06       12.69
# 1  Adams-Hemphill Neighborhood Park       21042   1.210141e+07        9.31
# 2           Agave Neighborhood Park        6157   1.068866e+07       16.36
# 3                 Alamo Pocket Park        6557   6.974684e+06        1.82
# 4            Alderbrook Pocket Park        5329   7.023673e+06        1.90
#
#    Normalized_byArea  Normalized_nonhis  Normalized_white  Normalized_hislat  \
# 0                100                 68                56                 32
# 1                704                595               437                109
# 2                 97                 16                 9                 81
# 3                618                550               404                 67
# 4               1212                898               716                314
#
#                           Park_Name  Total_Pop_Served  Non_Hispan  White  \
# 0    A.B. Dittmar Neighborhood Park              1273         865    711
# 1  Adams-Hemphill Neighborhood Park              6559        5540   4071
# 2           Agave Neighborhood Park              1599         265    152
# 3                 Alamo Pocket Park              1125        1002    736
# 4            Alderbrook Pocket Park              2303        1707   1362
#
#    Hispan_Latin
# 0           407
# 1          1021
# 2          1339
# 3           123
# 4           597

# %% [markdown]
# Descriptive Statistics

# %%
Race_access_stats = access_racetable.describe()
Race_access_stats.to_csv(wd+"data/access/access_stats_race_quarterbuff_ACS17.csv")
Race_access_stats
# Out:
#          Total_POP_  area_intersec   ASSET_SIZE  Normalized_byArea  \
# count    273.000000   2.730000e+02   273.000000         273.000000
# mean    9167.868132   1.168199e+07    48.405105         640.871795
# std     5995.121350   1.196448e+07   161.654150        1551.207756
# min     1244.000000   3.477550e+02     0.068466           0.000000
# 25%     5681.000000   6.678806e+06     2.901164          57.000000
# 50%     7479.000000   8.336906e+06     7.800000         187.000000
# 75%    10629.000000   1.135557e+07    20.299373         545.000000
# max    49429.000000   1.121726e+08  1885.441896       19365.000000
#
#        Normalized_nonhis  Normalized_white  Normalized_hislat  \
# count         273.000000        273.000000         273.000000
# mean          521.388278        431.633700         181.146520
# std          1706.768777       1485.640708         417.156376
# min             0.000000          0.000000           0.000000
# 25%            41.000000         27.000000          13.000000
# 50%           125.000000         91.000000          48.000000
# 75%           320.000000        268.000000         151.000000
# max         20280.000000      17400.000000        4008.000000
#
#        Total_Pop_Served    Non_Hispan         White  Hispan_Latin
# count        273.000000    273.000000    273.000000    273.000000
# mean        1864.142857   1267.989011    961.934066    698.659341
# std         1888.173481   1392.984928   1098.400282    959.513540
# min            0.000000      0.000000      0.000000      0.000000
# 25%          954.000000    654.000000    436.000000    148.000000
# 50%         1382.000000   1002.000000    761.000000    363.000000
# 75%         2191.000000   1398.000000   1096.000000    812.000000
# max        17678.000000  15457.000000  12548.000000   8802.000000

# %%
access_racetable.median()
# Out:
# Total_POP_           7.479000e+03
# area_intersec        8.336906e+06
# ASSET_SIZE           7.800000e+00
# Normalized_byArea    1.870000e+02
# Normalized_nonhis    1.250000e+02
# Normalized_white     9.100000e+01
# Normalized_hislat    4.800000e+01
# Total_Pop_Served     1.382000e+03
# Non_Hispan           1.002000e+03
# White                7.610000e+02
# Hispan_Latin         3.630000e+02
# dtype: float64

# %%
#access_racetable.hist('');

# %% [markdown]
# ##  <font color=goldenrod>Run spatial analysis on the amount of people distributed within a census block group against the quarter mile park buffer area and the income census data</font>

# %%
income.columns
# Out:
# Index(['level_0', 'index', 'GEOID10', 'ALAND10', 'AWATER10', 'area_ft',
#        'area_acres', 'jurisdic_3', 'modified_f', 'objectid', 'shape_area',
#        'shape_leng', 'Id', 'Id2', 'Total_Pop', 'Less than', '$10,000 to',
#        '$15,000 to', '$20,000 to', '$25,000 to', '$30,000 to', '$35,000 to',
#        '$40,000 to', '$45,000 to', '$50,000 to', '$60,000 to', '$75,000 to',
#        '$100,000 t', '$125,000 t', '$150,000 t', '$200,000 o', 'area_inter',
#        'weight', 'Total_POP_', 'Less tha_1', '$10,000 _1', '$15,000 _1',
#        '$20,000 _1', '$25,000 _1', '$30,000 _1', '$35,000 _1', '$40,000 _1',
#        '$45,000 _1', '$50,000 _1', '$60,000 _1', '$75,000 _1', '$100,000_1',
#        '$125,000_1', '$150,000_1', '$200,000_1', 'geometry',
#        'fullarea_income'],
#       dtype='object')

# %%
ip_intersection = gpd.overlay(income, quartbuff, how='intersection') #https://geopandas.org/set_operations.html
ip_intersection['iarea_intersec'] = ip_intersection['geometry'].area
ip_intersection.to_file(wd+"data/access/ip_intersec_quarterbuff_ACS17.shp")
ip_intersection
# Out:
#       level_0  index       GEOID10    ALAND10  AWATER10       area_ft  \
# 2           2      2  484530001011   950911.0       0.0  1.023445e+07
# 4           3      3  484530001012  1106260.0       0.0  1.190644e+07
# 8           4      4  484530001013  1069511.0       0.0  1.151098e+07
# 34          8      8  484530002041   514123.0       0.0  5.533474e+06
# 37          9      9  484530002042   551614.0       0.0  5.936942e+06
# ...       ...    ...           ...        ...       ...           ...
# 2196      542    542  484910204083   298417.0       0.0  3.211641e+06
# 2198      544    544  484910204092  1185181.0       0.0  1.275526e+07
# 2201      552    552  484910205081  4018118.0    2409.0  4.326969e+07
# 2206      556    556  484910205101  4745633.0    1268.0  5.108690e+07
# 2208      557    557  484910205103   346320.0       0.0  3.727163e+06
#
#       area_acres  jurisdic_3  modified_f  objectid  ...  GLOBALID  \
# 2        234.950       510.0      3150.0    1650.0  ...      None
# 4        273.332      1224.0      7560.0    3960.0  ...      None
# 8        264.255      1054.0      6510.0    3410.0  ...      None
# 34       127.033      1088.0      6720.0    3520.0  ...      None
# 37       136.293       816.0      5040.0    2640.0  ...      None
# ...          ...         ...         ...       ...  ...       ...
# 2196      73.729       170.0      1050.0     550.0  ...      None
# 2198     292.821       884.0      5460.0    2860.0  ...      None
# 2201     993.336       340.0      2100.0    1100.0  ...      None
# 2206    1172.794      1190.0      7350.0    3850.0  ...      None
# 2208      85.565       340.0      2100.0    1100.0  ...      None
#
#          CREATED_BY  CREATED_DA     MODIFIED_B  MODIFIED_D    Shape__Are  \
# 2     CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 4     CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 8     CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 34    CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 37    CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# ...             ...         ...            ...         ...           ...
# 2196  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  5.423833e+05
# 2198  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  5.423833e+05
# 2201  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05
# 2206  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05
# 2208  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05
#
#         Shape__Len  fullarea_buff  \
# 2     56641.286637   7.685576e+07
# 4     56641.286637   7.685576e+07
# 8     56641.286637   7.685576e+07
# 34    56641.286637   7.685576e+07
# 37    56641.286637   7.685576e+07
# ...            ...            ...
# 2196   2970.882179   9.386213e+06
# 2198   2970.882179   9.386213e+06
# 2201   3819.975953   1.025997e+07
# 2206   3819.975953   1.025997e+07
# 2208   3819.975953   1.025997e+07
#
#                                                geometry  iarea_intersec
# 2     (POLYGON ((3111310.380106392 10089474.08471978...    7.977811e+06
# 4     (POLYGON ((3110963.100224382 10092814.33601546...    3.558330e+05
# 8     POLYGON ((3110878.498096142 10085236.13059729,...    6.430365e+06
# 34    POLYGON ((3114161.352732578 10080856.88449187,...    2.730844e+06
# 37    (POLYGON ((3113607.519823685 10085639.98593919...    3.749049e+06
# ...                                                 ...             ...
# 2196  POLYGON ((3099402.330431718 10136725.68772296,...    6.554068e+05
# 2198  POLYGON ((3102295.150253439 10137882.6017911, ...    6.260890e+03
# 2201  POLYGON ((3103070.9294554 10151562.85760724, 3...    4.403025e+06
# 2206  (POLYGON ((3105356.685648966 10148942.41788262...    4.356998e+06
# 2208  POLYGON ((3104338.228040222 10151913.94934112,...    1.499946e+06
#
# [1420 rows x 107 columns]

# %%
ip_intersection.columns
# Out:
# Index(['level_0', 'index', 'GEOID10', 'ALAND10', 'AWATER10', 'area_ft',
#        'area_acres', 'jurisdic_3', 'modified_f', 'objectid',
#        ...
#        'GLOBALID', 'CREATED_BY', 'CREATED_DA', 'MODIFIED_B', 'MODIFIED_D',
#        'Shape__Are', 'Shape__Len', 'fullarea_buff', 'geometry',
#        'iarea_intersec'],
#       dtype='object', length=107)

# %%
ip_intersection[['GEOID10','Total_Pop','fullarea_income','LOCATION_N','fullarea_buff','iarea_intersec','geometry']]
# Out:
#            GEOID10  Total_Pop  fullarea_income                     LOCATION_N  \
# 2     484530001011        396     1.023445e+07          Shoal Creek Greenbelt
# 4     484530001012        476     1.190644e+07          Shoal Creek Greenbelt
# 8     484530001013       1154     1.151098e+07          Shoal Creek Greenbelt
# 34    484530002041        604     5.533474e+06          Shoal Creek Greenbelt
# 37    484530002042        635     5.936942e+06          Shoal Creek Greenbelt
# ...            ...        ...              ...                            ...
# 2196  484910204083        280     9.487768e+05  Springwoods Neighborhood Park
# 2198  484910204092        932     1.085400e+07  Springwoods Neighborhood Park
# 2201  484910205081       1733     3.682212e+07      Davis Spring Special Park
# 2206  484910205101       1366     3.462268e+07      Davis Spring Special Park
# 2208  484910205103        297     3.727163e+06      Davis Spring Special Park
#
#       fullarea_buff  iarea_intersec  \
# 2      7.685576e+07    7.977811e+06
# 4      7.685576e+07    3.558330e+05
# 8      7.685576e+07    6.430365e+06
# 34     7.685576e+07    2.730844e+06
# 37     7.685576e+07    3.749049e+06
# ...             ...             ...
# 2196   9.386213e+06    6.554068e+05
# 2198   9.386213e+06    6.260890e+03
# 2201   1.025997e+07    4.403025e+06
# 2206   1.025997e+07    4.356998e+06
# 2208   1.025997e+07    1.499946e+06
#
#                                                geometry
# 2     (POLYGON ((3111310.380106392 10089474.08471978...
# 4     (POLYGON ((3110963.100224382 10092814.33601546...
# 8     POLYGON ((3110878.498096142 10085236.13059729,...
# 34    POLYGON ((3114161.352732578 10080856.88449187,...
# 37    (POLYGON ((3113607.519823685 10085639.98593919...
# ...                                                 ...
# 2196  POLYGON ((3099402.330431718 10136725.68772296,...
# 2198  POLYGON ((3102295.150253439 10137882.6017911, ...
# 2201  POLYGON ((3103070.9294554 10151562.85760724, 3...
# 2206  (POLYGON ((3105356.685648966 10148942.41788262...
# 2208  POLYGON ((3104338.228040222 10151913.94934112,...
#
# [1420 rows x 7 columns]

# %%
ip_intersection.columns
# Out:
# Index(['level_0', 'index', 'GEOID10', 'ALAND10', 'AWATER10', 'area_ft',
#        'area_acres', 'jurisdic_3', 'modified_f', 'objectid',
#        ...
#        'GLOBALID', 'CREATED_BY', 'CREATED_DA', 'MODIFIED_B', 'MODIFIED_D',
#        'Shape__Are', 'Shape__Len', 'fullarea_buff', 'geometry',
#        'iarea_intersec'],
#       dtype='object', length=107)

# %%
income_clip=ip_intersection.copy()

for val in income_clip:

    income_clip['weight'] = income_clip['iarea_intersec']/ income_clip['fullarea_income']
    
    income_clip['Total Pop Served_allincomes'] = income_clip['weight'] * income_clip['Total_Pop']
    
    income_clip['Less than $25,000'] = ((income_clip['weight'] * income_clip['Less than'])\
                                        +(income_clip['weight'] * income_clip['$10,000 to'])\
                                        +(income_clip['weight'] * income_clip['$15,000 to'])\
                                        +(income_clip['weight'] * income_clip['$20,000 to']))
    
    income_clip['$25,000 to $49,999'] = ((income_clip['weight'] * income_clip['$25,000 to'])\
                                        +(income_clip['weight'] * income_clip['$30,000 to'])\
                                        +(income_clip['weight'] * income_clip['$35,000 to'])\
                                        +(income_clip['weight'] * income_clip['$40,000 to'])\
                                        +(income_clip['weight'] * income_clip['$45,000 to']))
    
    income_clip['$50,000 to $74,999'] = ((income_clip['weight'] * income_clip['$50,000 to'])\
                                        +(income_clip['weight'] * income_clip['$60,000 to']))
    
    income_clip['$75,000 to $99,999'] = (income_clip['weight'] * income_clip['$75,000 to'])
    
    income_clip['$100,000 to $149,999'] = ((income_clip['weight'] * income_clip['$100,000 t'])\
                                            +(income_clip['weight'] * income_clip['$125,000 t']))
    
    income_clip['$150,000 or more'] = ((income_clip['weight'] * income_clip['$150,000 t'])\
                                        +(income_clip['weight'] * income_clip['$200,000 o']))
    
income_clip.head()
# Out:
#     level_0  index       GEOID10    ALAND10  AWATER10       area_ft  \
# 2         2      2  484530001011   950911.0       0.0  1.023445e+07
# 4         3      3  484530001012  1106260.0       0.0  1.190644e+07
# 8         4      4  484530001013  1069511.0       0.0  1.151098e+07
# 34        8      8  484530002041   514123.0       0.0  5.533474e+06
# 37        9      9  484530002042   551614.0       0.0  5.936942e+06
#
#     area_acres  jurisdic_3  modified_f  objectid  ...  fullarea_buff  \
# 2      234.950       510.0      3150.0    1650.0  ...   7.685576e+07
# 4      273.332      1224.0      7560.0    3960.0  ...   7.685576e+07
# 8      264.255      1054.0      6510.0    3410.0  ...   7.685576e+07
# 34     127.033      1088.0      6720.0    3520.0  ...   7.685576e+07
# 37     136.293       816.0      5040.0    2640.0  ...   7.685576e+07
#
#                                              geometry iarea_intersec  \
# 2   (POLYGON ((3111310.380106392 10089474.08471978...   7.977811e+06
# 4   (POLYGON ((3110963.100224382 10092814.33601546...   3.558330e+05
# 8   POLYGON ((3110878.498096142 10085236.13059729,...   6.430365e+06
# 34  POLYGON ((3114161.352732578 10080856.88449187,...   2.730844e+06
# 37  (POLYGON ((3113607.519823685 10085639.98593919...   3.749049e+06
#
#    Total Pop Served_allincomes  Less than $25,000  $25,000 to $49,999  \
# 2                   308.684350          31.180237           30.400731
# 4                    14.225616           0.119543            0.687372
# 8                   644.657382          90.497830          103.904916
# 34                  298.082095         144.599427           52.312421
# 37                  400.988610          57.464510           46.097903
#
#     $50,000 to $74,999  $75,000 to $99,999  $100,000 to $149,999  \
# 2            47.549862           43.652332             44.431838
# 4             2.570174            0.448286              1.494287
# 8           134.070859           52.511087            141.891660
# 34           32.571885           16.779456              7.896214
# 37          118.086410           19.575822             44.834947
#
#     $150,000 or more
# 2         111.469349
# 4           8.905953
# 8         121.781031
# 34         43.922693
# 37        114.929019
#
# [5 rows x 114 columns]

# %%
#income_clip.columns

# %%
income_calc = income_clip[['LOCATION_N', 'Total_Pop','Total Pop Served_allincomes', 'Less than $25,000','$25,000 to $49,999',\
                           '$50,000 to $74,999','$75,000 to $99,999','$100,000 to $149,999','$150,000 or more','geometry']]

income_access_data = income_calc.dissolve(by='LOCATION_N',as_index=False, aggfunc='sum')

# %% [markdown]
# ##### Combine the park area data to the access data

# %%
income_access_data = income_access_data.merge(parks_, on='LOCATION_N')

# %%
income_access_data
# Out:
#                            LOCATION_N  \
# 0      A.B. Dittmar Neighborhood Park
# 1    Adams-Hemphill Neighborhood Park
# 2             Agave Neighborhood Park
# 3                   Alamo Pocket Park
# 4              Alderbrook Pocket Park
# ..                                ...
# 268          Wooten Neighborhood Park
# 269     Wunneburger Neighborhood Park
# 270                 Yates Pocket Park
# 271      Yett Creek Neighborhood Park
# 272                 Zilker Metro Park
#
#                                               geometry  Total_Pop  \
# 0    POLYGON ((3097945.260486613 10040357.04514253,...       2632
# 1    POLYGON ((3116425.666618853 10079471.33829271,...       4764
# 2    (POLYGON ((3145065.384555357 10081869.95696411...       1620
# 3    POLYGON ((3122655.295172911 10075520.37048018,...       2854
# 4    POLYGON ((3128917.516225351 10124262.76067684,...       2344
# ..                                                 ...        ...
# 268  POLYGON ((3121269.433041437 10100828.585948, 3...       3196
# 269  (POLYGON ((3095156.226719216 10021252.69393206...       1959
# 270  POLYGON ((3128555.312776149 10058188.62391765,...       2814
# 271  POLYGON ((3117329.523365858 10127115.06004296,...       3399
# 272  (POLYGON ((3105774.874722705 10073559.67186339...       8134
#
#      Total Pop Served_allincomes  Less than $25,000  $25,000 to $49,999  \
# 0                     536.472297          57.694242          180.019764
# 1                    2154.731306        1147.829088          425.025313
# 2                     377.576099          74.998774          178.269369
# 3                     496.361582          58.171022           97.614270
# 4                    1054.479309         122.428447          300.286259
# ..                           ...                ...                 ...
# 268                   711.089648         112.656426          203.305093
# 269                    37.899927           3.637155            7.738627
# 270                   423.652703         204.670750           51.449939
# 271                   387.359862           9.983287           51.645492
# 272                  1435.005509         141.768902          248.131074
#
#      $50,000 to $74,999  $75,000 to $99,999  $100,000 to $149,999  \
# 0            114.053707           68.418694             78.982003
# 1            226.609077          181.087563             25.554272
# 2             50.468126           30.412306             36.344342
# 3             95.205729           61.174188            119.777295
# 4            275.867198          133.180352            178.897838
# ..                  ...                 ...                   ...
# 268          186.788540           73.596003             89.827060
# 269            5.881357            7.216270              8.609223
# 270           60.777608           55.922901             36.290505
# 271           50.778884           91.706511             84.162781
# 272          245.178456          193.998991            277.701669
#
#      $150,000 or more  ASSET_SIZE
# 0           37.303887   12.690000
# 1          148.625993    9.310000
# 2            7.083182   16.360000
# 3           64.419077    1.820000
# 4           43.819215    1.900000
# ..                ...         ...
# 268         44.916526    6.280000
# 269          4.817295   23.510000
# 270         14.541000    0.933800
# 271         99.082907   40.545000
# 272        328.226416  307.849066
#
# [273 rows x 11 columns]

# %% [markdown]
# ##### The population served by parks is nomalized by dividing the population served by the area of the park for which they are being served

# %%
income_access_data['TotalPop_Served_norm'] = income_access_data['Total Pop Served_allincomes']/income_access_data['ASSET_SIZE']
income_access_data['Less than $25,000_norm'] = income_access_data['Less than $25,000']/income_access_data['ASSET_SIZE']
income_access_data['$25,000 to $49,999_norm'] = income_access_data['$25,000 to $49,999']/income_access_data['ASSET_SIZE']
income_access_data['$50,000 to $74,999_norm'] = income_access_data['$50,000 to $74,999']/income_access_data['ASSET_SIZE']
income_access_data['$75,000 to $99,999_norm'] = income_access_data['$75,000 to $99,999']/income_access_data['ASSET_SIZE']
income_access_data['$100,000 to $149,999_norm'] = income_access_data['$100,000 to $149,999']/income_access_data['ASSET_SIZE']
income_access_data['$150,000 or more_norm'] = income_access_data['$150,000 or more']/income_access_data['ASSET_SIZE']

# %%
income_access_data.to_file(wd+"data/access/access_data_income_quarterbuff_ACS17.shp")
income_access_data
# Out:
#                            LOCATION_N  \
# 0      A.B. Dittmar Neighborhood Park
# 1    Adams-Hemphill Neighborhood Park
# 2             Agave Neighborhood Park
# 3                   Alamo Pocket Park
# 4              Alderbrook Pocket Park
# ..                                ...
# 268          Wooten Neighborhood Park
# 269     Wunneburger Neighborhood Park
# 270                 Yates Pocket Park
# 271      Yett Creek Neighborhood Park
# 272                 Zilker Metro Park
#
#                                               geometry  Total_Pop  \
# 0    POLYGON ((3097945.260486613 10040357.04514253,...       2632
# 1    POLYGON ((3116425.666618853 10079471.33829271,...       4764
# 2    (POLYGON ((3145065.384555357 10081869.95696411...       1620
# 3    POLYGON ((3122655.295172911 10075520.37048018,...       2854
# 4    POLYGON ((3128917.516225351 10124262.76067684,...       2344
# ..                                                 ...        ...
# 268  POLYGON ((3121269.433041437 10100828.585948, 3...       3196
# 269  (POLYGON ((3095156.226719216 10021252.69393206...       1959
# 270  POLYGON ((3128555.312776149 10058188.62391765,...       2814
# 271  POLYGON ((3117329.523365858 10127115.06004296,...       3399
# 272  (POLYGON ((3105774.874722705 10073559.67186339...       8134
#
#      Total Pop Served_allincomes  Less than $25,000  $25,000 to $49,999  \
# 0                     536.472297          57.694242          180.019764
# 1                    2154.731306        1147.829088          425.025313
# 2                     377.576099          74.998774          178.269369
# 3                     496.361582          58.171022           97.614270
# 4                    1054.479309         122.428447          300.286259
# ..                           ...                ...                 ...
# 268                   711.089648         112.656426          203.305093
# 269                    37.899927           3.637155            7.738627
# 270                   423.652703         204.670750           51.449939
# 271                   387.359862           9.983287           51.645492
# 272                  1435.005509         141.768902          248.131074
#
#      $50,000 to $74,999  $75,000 to $99,999  $100,000 to $149,999  \
# 0            114.053707           68.418694             78.982003
# 1            226.609077          181.087563             25.554272
# 2             50.468126           30.412306             36.344342
# 3             95.205729           61.174188            119.777295
# 4            275.867198          133.180352            178.897838
# ..                  ...                 ...                   ...
# 268          186.788540           73.596003             89.827060
# 269            5.881357            7.216270              8.609223
# 270           60.777608           55.922901             36.290505
# 271           50.778884           91.706511             84.162781
# 272          245.178456          193.998991            277.701669
#
#      $150,000 or more  ASSET_SIZE  TotalPop_Served_norm  \
# 0           37.303887   12.690000             42.275201
# 1          148.625993    9.310000            231.442675
# 2            7.083182   16.360000             23.079224
# 3           64.419077    1.820000            272.726144
# 4           43.819215    1.900000            554.989110
# ..                ...         ...                   ...
# 268         44.916526    6.280000            113.230836
# 269          4.817295   23.510000              1.612077
# 270         14.541000    0.933800            453.686767
# 271         99.082907   40.545000              9.553826
# 272        328.226416  307.849066              4.661393
#
#      Less than $25,000_norm  $25,000 to $49,999_norm  $50,000 to $74,999_norm  \
# 0                  4.546434                14.185955                 8.987684
# 1                123.289913                45.652558                24.340395
# 2                  4.584277                10.896661                 3.084849
# 3                 31.962100                53.634214                52.310840
# 4                 64.436025               158.045400               145.193262
# ..                      ...                      ...                      ...
# 268               17.938921                32.373422                29.743398
# 269                0.154707                 0.329163                 0.250164
# 270              219.180499                55.097386                65.086323
# 271                0.246227                 1.273782                 1.252408
# 272                0.460514                 0.806015                 0.796424
#
#      $75,000 to $99,999_norm  $100,000 to $149,999_norm  $150,000 or more_norm
# 0                   5.391544                   6.223956               2.939629
# 1                  19.450866                   2.744820              15.964124
# 2                   1.858943                   2.221537               0.432957
# 3                  33.612191                  65.811701              35.395097
# 4                  70.094922                  94.156757              23.062745
# ..                       ...                        ...                    ...
# 268                11.719109                  14.303672               7.152313
# 269                 0.306945                   0.366194               0.204904
# 270                59.887450                  38.863253              15.571857
# 271                 2.261845                   2.075787               2.443776
# 272                 0.630176                   0.902071               1.066193
#
# [273 rows x 18 columns]

# %% [markdown]
# #### A dataframe is created with the 'acess_data' geoshapefile. This dataframe is cleaned up and the values are convereted into integers. Finally, we export the dataframe into a csv file and a shapefile.

# %%
df1 = pd.DataFrame(income_access_data)
df1['Park_Name']=df1['LOCATION_N']

df1['Total Pop Served_allincomes'] = df1['Total Pop Served_allincomes'].astype(int)
df1['TotalPop_Served_norm'] = df1['TotalPop_Served_norm'].astype(int)

df1['Less than $25,000'] = df1['Less than $25,000'].astype(int)
df1['Less than $25,000_norm'] = df1['Less than $25,000_norm'].astype(int)

df1['$25,000 to $49,999'] = df1['$25,000 to $49,999'].astype(int)
df1['$25,000 to $49,999_norm'] = df1['$25,000 to $49,999_norm'].astype(int)

df1['$50,000 to $74,999'] = df1['$50,000 to $74,999'].astype(int)
df1['$50,000 to $74,999_norm'] = df1['$50,000 to $74,999_norm'].astype(int)

df1['$75,000 to $99,999'] = df1['$75,000 to $99,999'].astype(int)
df1['$75,000 to $99,999_norm'] = df1['$75,000 to $99,999_norm'].astype(int)

df1['$100,000 to $149,999'] = df1['$100,000 to $149,999'].astype(int)
df1['$100,000 to $149,999_norm'] = df1['$100,000 to $149,999_norm'].astype(int)

df1['$150,000 or more'] = df1['$150,000 or more'].astype(int)
df1['$150,000 or more_norm'] = df1['$150,000 or more_norm'].astype(int)

# %%
access_income_final = df1.copy()
access_income_final = gpd.GeoDataFrame(access_income_final, geometry='geometry')
access_income_final.to_file(wd+"data/access/access_income_final_quarterbuff_ACS17.shp")
access_income_final.head()
# Out:
#                          LOCATION_N  \
# 0    A.B. Dittmar Neighborhood Park
# 1  Adams-Hemphill Neighborhood Park
# 2           Agave Neighborhood Park
# 3                 Alamo Pocket Park
# 4            Alderbrook Pocket Park
#
#                                             geometry  Total_Pop  \
# 0  POLYGON ((3097945.260486613 10040357.04514253,...       2632
# 1  POLYGON ((3116425.666618853 10079471.33829271,...       4764
# 2  (POLYGON ((3145065.384555357 10081869.95696411...       1620
# 3  POLYGON ((3122655.295172911 10075520.37048018,...       2854
# 4  POLYGON ((3128917.516225351 10124262.76067684,...       2344
#
#    Total Pop Served_allincomes  Less than $25,000  $25,000 to $49,999  \
# 0                          536                 57                 180
# 1                         2154               1147                 425
# 2                          377                 74                 178
# 3                          496                 58                  97
# 4                         1054                122                 300
#
#    $50,000 to $74,999  $75,000 to $99,999  $100,000 to $149,999  \
# 0                 114                  68                    78
# 1                 226                 181                    25
# 2                  50                  30                    36
# 3                  95                  61                   119
# 4                 275                 133                   178
#
#    $150,000 or more  ASSET_SIZE  TotalPop_Served_norm  Less than $25,000_norm  \
# 0                37       12.69                    42                       4
# 1               148        9.31                   231                     123
# 2                 7       16.36                    23                       4
# 3                64        1.82                   272                      31
# 4                43        1.90                   554                      64
#
#    $25,000 to $49,999_norm  $50,000 to $74,999_norm  $75,000 to $99,999_norm  \
# 0                       14                        8                        5
# 1                       45                       24                       19
# 2                       10                        3                        1
# 3                       53                       52                       33
# 4                      158                      145                       70
#
#    $100,000 to $149,999_norm  $150,000 or more_norm  \
# 0                          6                      2
# 1                          2                     15
# 2                          2                      0
# 3                         65                     35
# 4                         94                     23
#
#                           Park_Name
# 0    A.B. Dittmar Neighborhood Park
# 1  Adams-Hemphill Neighborhood Park
# 2           Agave Neighborhood Park
# 3                 Alamo Pocket Park
# 4            Alderbrook Pocket Park

# %%
access_incometable = df.drop(columns=['geometry'])
access_incometable.to_csv(wd+"data/access/access_table_income_quarterbuff_ACS17.csv")
access_incometable.head()
# Out:
#                          LOCATION_N  Total_POP_   access_pop  access_nonhis  \
# 0    A.B. Dittmar Neighborhood Park        6626  1273.144971     865.679107
# 1  Adams-Hemphill Neighborhood Park       21042  6559.199112    5540.140840
# 2           Agave Neighborhood Park        6157  1599.033656     265.761114
# 3                 Alamo Pocket Park        6557  1125.732090    1002.439231
# 4            Alderbrook Pocket Park        5329  2303.375334    1707.181710
#
#    access_white  access_his_lat  area_intersec  ASSET_SIZE  Normalized_byArea  \
# 0    711.176368      407.719306   8.989080e+06       12.69                100
# 1   4071.105492     1021.355082   1.210141e+07        9.31                704
# 2    152.212052     1339.556558   1.068866e+07       16.36                 97
# 3    736.495784      123.540364   6.974684e+06        1.82                618
# 4   1362.143073      597.158742   7.023673e+06        1.90               1212
#
#    Normalized_nonhis  Normalized_white  Normalized_hislat  \
# 0                 68                56                 32
# 1                595               437                109
# 2                 16                 9                 81
# 3                550               404                 67
# 4                898               716                314
#
#                           Park_Name  Total_Pop_Served  Non_Hispan  White  \
# 0    A.B. Dittmar Neighborhood Park              1273         865    711
# 1  Adams-Hemphill Neighborhood Park              6559        5540   4071
# 2           Agave Neighborhood Park              1599         265    152
# 3                 Alamo Pocket Park              1125        1002    736
# 4            Alderbrook Pocket Park              2303        1707   1362
#
#    Hispan_Latin
# 0           407
# 1          1021
# 2          1339
# 3           123
# 4           597

# %%
access_income_stats = access_incometable.describe()
access_income_stats.to_csv(wd+"data/access/access_stats_income_quarterbuff_ACS17.csv")
access_income_stats
# Out:
#          Total_POP_    access_pop  access_nonhis  access_white  \
# count    273.000000    273.000000     273.000000    273.000000
# mean    9167.868132   1864.649710    1268.457935    962.419128
# std     5995.121350   1888.168747    1392.997187   1098.385522
# min     1244.000000      0.033750       0.033627      0.028605
# 25%     5681.000000    954.073706     654.184101    436.088445
# 50%     7479.000000   1382.622676    1002.439231    761.889765
# 75%    10629.000000   2191.919486    1398.550442   1096.600521
# max    49429.000000  17678.150171   15457.447401  12548.155414
#
#        access_his_lat  area_intersec   ASSET_SIZE  Normalized_byArea  \
# count      273.000000   2.730000e+02   273.000000         273.000000
# mean       699.166731   1.168199e+07    48.405105         640.871795
# std        959.538686   1.196448e+07   161.654150        1551.207756
# min          0.021663   3.477550e+02     0.068466           0.000000
# 25%        148.091195   6.678806e+06     2.901164          57.000000
# 50%        363.894473   8.336906e+06     7.800000         187.000000
# 75%        812.095454   1.135557e+07    20.299373         545.000000
# max       8802.983056   1.121726e+08  1885.441896       19365.000000
#
#        Normalized_nonhis  Normalized_white  Normalized_hislat  \
# count         273.000000        273.000000         273.000000
# mean          521.388278        431.633700         181.146520
# std          1706.768777       1485.640708         417.156376
# min             0.000000          0.000000           0.000000
# 25%            41.000000         27.000000          13.000000
# 50%           125.000000         91.000000          48.000000
# 75%           320.000000        268.000000         151.000000
# max         20280.000000      17400.000000        4008.000000
#
#        Total_Pop_Served    Non_Hispan         White  Hispan_Latin
# count        273.000000    273.000000    273.000000    273.000000
# mean        1864.142857   1267.989011    961.934066    698.659341
# std         1888.173481   1392.984928   1098.400282    959.513540
# min            0.000000      0.000000      0.000000      0.000000
# 25%          954.000000    654.000000    436.000000    148.000000
# 50%         1382.000000   1002.000000    761.000000    363.000000
# 75%         2191.000000   1398.000000   1096.000000    812.000000
# max        17678.000000  15457.000000  12548.000000   8802.000000

# %% [markdown]
# ## <font color=peru>Run spatial analysis on the amount of people distributed within a census block group against the quarter mile park buffer area and the age/sex census data</font>

# %%
age_intersection = gpd.overlay(age, quartbuff, how='intersection') #https://geopandas.org/set_operations.html
age_intersection['agearea_intersec'] = age_intersection['geometry'].area
age_intersection.to_file(wd+"data/access/age_intersec_quarterbuff_ACS17.shp")

age_intersection
# Out:
#       level_0  index       GEOID10    ALAND10  AWATER10       area_ft  \
# 1           0      2  484530001011   950911.0       0.0  1.023445e+07
# 3           1      3  484530001012  1106260.0       0.0  1.190644e+07
# 7           2      4  484530001013  1069511.0       0.0  1.151098e+07
# 33          6      8  484530002041   514123.0       0.0  5.533474e+06
# 36          7      9  484530002042   551614.0       0.0  5.936942e+06
# ...       ...    ...           ...        ...       ...           ...
# 2195      540    542  484910204083   298417.0       0.0  3.211641e+06
# 2197      542    544  484910204092  1185181.0       0.0  1.275526e+07
# 2200      550    552  484910205081  4018118.0    2409.0  4.326969e+07
# 2205      554    556  484910205101  4745633.0    1268.0  5.108690e+07
# 2207      555    557  484910205103   346320.0       0.0  3.727163e+06
#
#       area_acres  jurisdic_3  modified_f  objectid  ...  GLOBALID  \
# 1        234.950       510.0      3150.0    1650.0  ...      None
# 3        273.332      1224.0      7560.0    3960.0  ...      None
# 7        264.255      1054.0      6510.0    3410.0  ...      None
# 33       127.033      1088.0      6720.0    3520.0  ...      None
# 36       136.293       816.0      5040.0    2640.0  ...      None
# ...          ...         ...         ...       ...  ...       ...
# 2195      73.729       170.0      1050.0     550.0  ...      None
# 2197     292.821       884.0      5460.0    2860.0  ...      None
# 2200     993.336       340.0      2100.0    1100.0  ...      None
# 2205    1172.794      1190.0      7350.0    3850.0  ...      None
# 2207      85.565       340.0      2100.0    1100.0  ...      None
#
#          CREATED_BY  CREATED_DA     MODIFIED_B  MODIFIED_D    Shape__Are  \
# 1     CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 3     CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 7     CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 33    CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# 36    CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06
# ...             ...         ...            ...         ...           ...
# 2195  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  5.423833e+05
# 2197  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  5.423833e+05
# 2200  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05
# 2205  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05
# 2207  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05
#
#         Shape__Len  fullarea_buff  \
# 1     56641.286637   7.685576e+07
# 3     56641.286637   7.685576e+07
# 7     56641.286637   7.685576e+07
# 33    56641.286637   7.685576e+07
# 36    56641.286637   7.685576e+07
# ...            ...            ...
# 2195   2970.882179   9.386213e+06
# 2197   2970.882179   9.386213e+06
# 2200   3819.975953   1.025997e+07
# 2205   3819.975953   1.025997e+07
# 2207   3819.975953   1.025997e+07
#
#                                                geometry  agearea_intersec
# 1     (POLYGON ((3111310.380106392 10089474.08471978...      7.977811e+06
# 3     (POLYGON ((3110963.100224382 10092814.33601546...      3.558330e+05
# 7     POLYGON ((3110878.498096142 10085236.13059729,...      6.430365e+06
# 33    POLYGON ((3114161.352732578 10080856.88449187,...      2.730844e+06
# 36    (POLYGON ((3113607.519823685 10085639.98593919...      3.749049e+06
# ...                                                 ...               ...
# 2195  POLYGON ((3099402.330431718 10136725.68772296,...      6.554068e+05
# 2197  POLYGON ((3102295.150253439 10137882.6017911, ...      6.260890e+03
# 2200  POLYGON ((3103070.9294554 10151562.85760724, 3...      4.403025e+06
# 2205  (POLYGON ((3105356.685648966 10148942.41788262...      4.356998e+06
# 2207  POLYGON ((3104338.228040222 10151913.94934112,...      1.499946e+06
#
# [1420 rows x 136 columns]

# %%
age_intersec=age_intersection.drop(['GLOBALID', 'CREATED_BY', 'CREATED_DA', 'MODIFIED_B', 'MODIFIED_D',
       'Shape__Are', 'Shape__Len', 'fullarea_buff','MXASSETNUM', 'MXLOCATION', 'MXSITEID', 'MXCREATION', 'MXSTATUS',
       'MXCONDITIO', 'MXPRIORITY', 'MXLOADID'], axis=1)

# %%
age_intersec.columns
# Out:
# Index(['level_0', 'index', 'GEOID10', 'ALAND10', 'AWATER10', 'area_ft',
#        'area_acres', 'jurisdic_3', 'modified_f', 'objectid',
#        ...
#        'ACQUISIT_2', 'DEVELOPM_1', 'DEVELOPM_2', 'RESTRICTIO', 'LWCF_PROTE',
#        'OTHER_PROT', 'REST_PROT_', 'COMMUNITY_', 'geometry',
#        'agearea_intersec'],
#       dtype='object', length=120)

# %%
age_intersection[['GEOID10','Total_pop_','fullarea_age','LOCATION_N','fullarea_buff','agearea_intersec','geometry']]
# Out:
#            GEOID10  Total_pop_  fullarea_age                     LOCATION_N  \
# 1     484530001011        1045  1.023445e+07          Shoal Creek Greenbelt
# 3     484530001012        1202  1.190644e+07          Shoal Creek Greenbelt
# 7     484530001013        2016  1.151098e+07          Shoal Creek Greenbelt
# 33    484530002041        1113  5.533474e+06          Shoal Creek Greenbelt
# 36    484530002042        1255  5.936942e+06          Shoal Creek Greenbelt
# ...            ...         ...           ...                            ...
# 2195  484910204083         835  9.487768e+05  Springwoods Neighborhood Park
# 2197  484910204092        2479  1.085400e+07  Springwoods Neighborhood Park
# 2200  484910205081        3775  3.682212e+07      Davis Spring Special Park
# 2205  484910205101        4695  3.462268e+07      Davis Spring Special Park
# 2207  484910205103         929  3.727163e+06      Davis Spring Special Park
#
#       fullarea_buff  agearea_intersec  \
# 1      7.685576e+07      7.977811e+06
# 3      7.685576e+07      3.558330e+05
# 7      7.685576e+07      6.430365e+06
# 33     7.685576e+07      2.730844e+06
# 36     7.685576e+07      3.749049e+06
# ...             ...               ...
# 2195   9.386213e+06      6.554068e+05
# 2197   9.386213e+06      6.260890e+03
# 2200   1.025997e+07      4.403025e+06
# 2205   1.025997e+07      4.356998e+06
# 2207   1.025997e+07      1.499946e+06
#
#                                                geometry
# 1     (POLYGON ((3111310.380106392 10089474.08471978...
# 3     (POLYGON ((3110963.100224382 10092814.33601546...
# 7     POLYGON ((3110878.498096142 10085236.13059729,...
# 33    POLYGON ((3114161.352732578 10080856.88449187,...
# 36    (POLYGON ((3113607.519823685 10085639.98593919...
# ...                                                 ...
# 2195  POLYGON ((3099402.330431718 10136725.68772296,...
# 2197  POLYGON ((3102295.150253439 10137882.6017911, ...
# 2200  POLYGON ((3103070.9294554 10151562.85760724, 3...
# 2205  (POLYGON ((3105356.685648966 10148942.41788262...
# 2207  POLYGON ((3104338.228040222 10151913.94934112,...
#
# [1420 rows x 7 columns]

# %%
age_intersec.columns
# Out:
# Index(['level_0', 'index', 'GEOID10', 'ALAND10', 'AWATER10', 'area_ft',
#        'area_acres', 'jurisdic_3', 'modified_f', 'objectid',
#        ...
#        'ACQUISIT_2', 'DEVELOPM_1', 'DEVELOPM_2', 'RESTRICTIO', 'LWCF_PROTE',
#        'OTHER_PROT', 'REST_PROT_', 'COMMUNITY_', 'geometry',
#        'agearea_intersec'],
#       dtype='object', length=120)

# %%
age_clip=age_intersec.copy()

for val in age_clip:

    age_clip['weight'] = age_clip['agearea_intersec']/ age_clip['fullarea_age']
    
    age_clip['Totalpop_served'] = age_clip['weight'] * age_clip['Total_pop_']
    age_clip['Males_served'] = age_clip['weight'] * age_clip['Male_new']
    age_clip['Males_served_Under5'] = age_clip['weight'] * age_clip['Male_Under']
    age_clip['Males_served_Under18'] = age_clip['weight'] * age_clip['Male_Und_1']
    age_clip['Males_served_Over65'] = age_clip['weight'] * age_clip['Male_Over6']
    
    age_clip['Females_served'] = age_clip['weight'] * age_clip['Female']
    age_clip['Females_served_Under5'] = age_clip['weight'] * age_clip['Female_Und']
    age_clip['Females_served_Under18'] = age_clip['weight'] * age_clip['Female_U_1']
    age_clip['Females_served_Over65'] = age_clip['weight'] * age_clip['Female_Ove']
        
age_clip.head()
# Out:
#     level_0  index       GEOID10    ALAND10  AWATER10       area_ft  \
# 1         0      2  484530001011   950911.0       0.0  1.023445e+07
# 3         1      3  484530001012  1106260.0       0.0  1.190644e+07
# 7         2      4  484530001013  1069511.0       0.0  1.151098e+07
# 33        6      8  484530002041   514123.0       0.0  5.533474e+06
# 36        7      9  484530002042   551614.0       0.0  5.936942e+06
#
#     area_acres  jurisdic_3  modified_f  objectid  ...  agearea_intersec  \
# 1      234.950       510.0      3150.0    1650.0  ...      7.977811e+06
# 3      273.332      1224.0      7560.0    3960.0  ...      3.558330e+05
# 7      264.255      1054.0      6510.0    3410.0  ...      6.430365e+06
# 33     127.033      1088.0      6720.0    3520.0  ...      2.730844e+06
# 36     136.293       816.0      5040.0    2640.0  ...      3.749049e+06
#
#     Totalpop_served Males_served Males_served_Under5  Males_served_Under18  \
# 1        814.583701   401.445556           56.124427            137.193044
# 3         35.922669    17.901563            1.105773              3.167889
# 7       1126.195219   444.668350           24.021029             65.918173
# 33       549.280417   378.524779            3.454594             29.117291
# 36       792.505049   422.458867            3.788869             37.888688
#
#     Males_served_Over65  Females_served  Females_served_Under5  \
# 1             50.667886      413.138145              18.708142
# 3              1.285087       18.021106               1.882802
# 7             77.090744      680.409611              37.986743
# 33             9.870268      169.768610              13.324862
# 36            80.829200      368.783226              13.892519
#
#     Females_served_Under18  Females_served_Over65
# 1                74.832570              35.077767
# 3                 5.498978               2.002345
# 7                85.470173             222.334175
# 33               28.623777               7.402701
# 36               59.990422              82.092156
#
# [5 rows x 129 columns]

# %%
#income_clip.columns

# %%
age_calc = age_clip[['LOCATION_N','Total_pop_', 'Totalpop_served', 'Males_served','Males_served_Under5','Males_served_Under18',\
                     'Males_served_Over65','Females_served','Females_served_Under5','Females_served_Under18',\
                     'Females_served_Over65','geometry']]

age_access_data = age_calc.dissolve(by='LOCATION_N',as_index=False, aggfunc='sum')

# %% [markdown]
# ##### Combine the park area data to the access data

# %%
age_access_data = age_access_data.merge(parks_, on='LOCATION_N')

# %%
age_access_data
# Out:
#                            LOCATION_N  \
# 0      A.B. Dittmar Neighborhood Park
# 1    Adams-Hemphill Neighborhood Park
# 2             Agave Neighborhood Park
# 3                   Alamo Pocket Park
# 4              Alderbrook Pocket Park
# ..                                ...
# 268          Wooten Neighborhood Park
# 269     Wunneburger Neighborhood Park
# 270                 Yates Pocket Park
# 271      Yett Creek Neighborhood Park
# 272                 Zilker Metro Park
#
#                                               geometry  Total_pop_  \
# 0    POLYGON ((3097945.260486613 10040357.04514253,...        6628
# 1    POLYGON ((3116425.666618853 10079471.33829271,...       21048
# 2    (POLYGON ((3145065.384555357 10081869.95696411...        6201
# 3    POLYGON ((3122655.295172911 10075520.37048018,...        6559
# 4    POLYGON ((3128917.516225351 10124262.76067684,...        5332
# ..                                                 ...         ...
# 268  POLYGON ((3121269.433041437 10100828.585948, 3...        7928
# 269  (POLYGON ((3095156.226719216 10021252.69393206...        4954
# 270  POLYGON ((3128555.312776149 10058188.62391765,...        8795
# 271  POLYGON ((3117329.523365858 10127115.06004296,...        8098
# 272  (POLYGON ((3105774.874722705 10073559.67186339...       15773
#
#      Totalpop_served  Males_served  Males_served_Under5  Males_served_Under18  \
# 0        1273.398413    653.171310            58.324535            131.691245
# 1        6561.495922   2965.976237             4.693248             59.929594
# 2        1605.317671    786.514951           119.828826            306.054068
# 3        1125.979596    625.076000            17.880884             32.742481
# 4        2304.340451    974.038200            44.973398            119.833020
# ..               ...           ...                  ...                   ...
# 268      1980.438069   1038.052855           197.699620            272.949220
# 269        95.842898     29.426130             3.172837              9.537858
# 270      1380.701500    758.304070            63.431559            169.166575
# 271       911.865422    449.455244            24.166782             64.557130
# 272      2544.577769   1279.054085            69.261363            132.390812
#
#      Males_served_Over65  Females_served  Females_served_Under5  \
# 0              48.097151      619.720220              25.009715
# 1              75.900234     3590.926064              71.401914
# 2              27.742081      811.733060             111.062602
# 3              23.114997      500.408583              16.543236
# 4              17.632987     1328.372017              83.662041
# ..                   ...             ...                    ...
# 268            49.221313      942.211839              54.488982
# 269             5.281613       29.058545               1.857271
# 270            20.507943      622.297041              12.423808
# 271            75.083884      423.960334              35.248665
# 272            99.336335     1255.952062             105.554886
#
#      Females_served_Under18  Females_served_Over65  ASSET_SIZE
# 0                 78.280032              57.474791   12.690000
# 1                192.619176              12.728434    9.310000
# 2                347.713568              38.479566   16.360000
# 3                 51.171730              44.066326    1.820000
# 4                210.102560             176.416045    1.900000
# ..                      ...                    ...         ...
# 268              240.942296             112.885822    6.280000
# 269                8.667262               5.687891   23.510000
# 270              125.530557              47.823091    0.933800
# 271               76.596073              78.095084   40.545000
# 272              174.577773             122.804185  307.849066
#
# [273 rows x 13 columns]

# %%
age_access_data.columns
# Out:
# Index(['LOCATION_N', 'geometry', 'Total_pop_', 'Totalpop_served',
#        'Males_served', 'Males_served_Under5', 'Males_served_Under18',
#        'Males_served_Over65', 'Females_served', 'Females_served_Under5',
#        'Females_served_Under18', 'Females_served_Over65', 'ASSET_SIZE'],
#       dtype='object')

# %% [markdown]
# ##### The population served by parks is nomalized by dividing the population served by the area of the park for which they are being served

# %%
age_access_data['Totalpop_served_norm'] = age_access_data['Totalpop_served']/age_access_data['ASSET_SIZE']
age_access_data['Males_served_norm'] = age_access_data['Males_served']/age_access_data['ASSET_SIZE']
age_access_data['Males_served_Under5_norm'] = age_access_data['Males_served_Under5']/age_access_data['ASSET_SIZE']
age_access_data['Males_served_Under18_norm'] = age_access_data['Males_served_Under18']/age_access_data['ASSET_SIZE']
age_access_data['Males_served_Over65_norm'] = age_access_data['Males_served_Over65']/age_access_data['ASSET_SIZE']

age_access_data['Females_served_norm'] = age_access_data['Females_served']/age_access_data['ASSET_SIZE']
age_access_data['Females_served_Under5_norm'] = age_access_data['Females_served_Under5']/age_access_data['ASSET_SIZE']
age_access_data['Females_served_Under18_norm'] = age_access_data['Females_served_Under18']/age_access_data['ASSET_SIZE']
age_access_data['Females_served_Over65_norm'] = age_access_data['Females_served_Over65']/age_access_data['ASSET_SIZE']

age_access_data['Under5_served'] = age_access_data['Males_served_Under5'] + age_access_data['Females_served_Under5']
age_access_data['Under5_served_norm'] = age_access_data['Under5_served']/age_access_data['ASSET_SIZE']

age_access_data['Under18_served'] = age_access_data['Males_served_Under18'] + age_access_data['Females_served_Under18']
age_access_data['Under18_served_norm'] = age_access_data['Under18_served']/age_access_data['ASSET_SIZE']

age_access_data['Over65_served'] = age_access_data['Males_served_Over65'] + age_access_data['Females_served_Over65']
age_access_data['Over65_served_norm'] = age_access_data['Over65_served']/age_access_data['ASSET_SIZE']

age_access_data['Women_Children_under5']= age_access_data['Females_served'] + age_access_data['Males_served_Under5']
age_access_data['Women_Children_under5_norm']= age_access_data['Women_Children_under5']/age_access_data['ASSET_SIZE']

age_access_data['Women_Children_under18']= age_access_data['Females_served'] + age_access_data['Males_served_Under18']
age_access_data['Women_Children_under18_norm']= age_access_data['Women_Children_under18']/age_access_data['ASSET_SIZE']

# %%
age_access_data.to_file(wd+"data/access/access_data_age_sex_quarterbuff_ACS17.shp")
age_access_data
# Out:
#                            LOCATION_N  \
# 0      A.B. Dittmar Neighborhood Park
# 1    Adams-Hemphill Neighborhood Park
# 2             Agave Neighborhood Park
# 3                   Alamo Pocket Park
# 4              Alderbrook Pocket Park
# ..                                ...
# 268          Wooten Neighborhood Park
# 269     Wunneburger Neighborhood Park
# 270                 Yates Pocket Park
# 271      Yett Creek Neighborhood Park
# 272                 Zilker Metro Park
#
#                                               geometry  Total_pop_  \
# 0    POLYGON ((3097945.260486613 10040357.04514253,...        6628
# 1    POLYGON ((3116425.666618853 10079471.33829271,...       21048
# 2    (POLYGON ((3145065.384555357 10081869.95696411...        6201
# 3    POLYGON ((3122655.295172911 10075520.37048018,...        6559
# 4    POLYGON ((3128917.516225351 10124262.76067684,...        5332
# ..                                                 ...         ...
# 268  POLYGON ((3121269.433041437 10100828.585948, 3...        7928
# 269  (POLYGON ((3095156.226719216 10021252.69393206...        4954
# 270  POLYGON ((3128555.312776149 10058188.62391765,...        8795
# 271  POLYGON ((3117329.523365858 10127115.06004296,...        8098
# 272  (POLYGON ((3105774.874722705 10073559.67186339...       15773
#
#      Totalpop_served  Males_served  Males_served_Under5  Males_served_Under18  \
# 0        1273.398413    653.171310            58.324535            131.691245
# 1        6561.495922   2965.976237             4.693248             59.929594
# 2        1605.317671    786.514951           119.828826            306.054068
# 3        1125.979596    625.076000            17.880884             32.742481
# 4        2304.340451    974.038200            44.973398            119.833020
# ..               ...           ...                  ...                   ...
# 268      1980.438069   1038.052855           197.699620            272.949220
# 269        95.842898     29.426130             3.172837              9.537858
# 270      1380.701500    758.304070            63.431559            169.166575
# 271       911.865422    449.455244            24.166782             64.557130
# 272      2544.577769   1279.054085            69.261363            132.390812
#
#      Males_served_Over65  Females_served  Females_served_Under5  ...  \
# 0              48.097151      619.720220              25.009715  ...
# 1              75.900234     3590.926064              71.401914  ...
# 2              27.742081      811.733060             111.062602  ...
# 3              23.114997      500.408583              16.543236  ...
# 4              17.632987     1328.372017              83.662041  ...
# ..                   ...             ...                    ...  ...
# 268            49.221313      942.211839              54.488982  ...
# 269             5.281613       29.058545               1.857271  ...
# 270            20.507943      622.297041              12.423808  ...
# 271            75.083884      423.960334              35.248665  ...
# 272            99.336335     1255.952062             105.554886  ...
#
#      Under5_served  Under5_served_norm  Under18_served  Under18_served_norm  \
# 0        83.334250            6.566923      209.971277            16.546200
# 1        76.095162            8.173487      252.548771            27.126613
# 2       230.891428           14.113168      653.767636            39.961347
# 3        34.424120           18.914352       83.914211            46.106709
# 4       128.635439           67.702863      329.935580           173.650305
# ..             ...                 ...             ...                  ...
# 268     252.188602           40.157421      513.891516            81.829859
# 269       5.030108            0.213956       18.205120             0.774356
# 270      75.855367           81.232991      294.697132           315.589133
# 271      59.415446            1.465420      141.153204             3.481396
# 272     174.816250            0.567864      306.968585             0.997140
#
#      Over65_served  Over65_served_norm  Women_Children_under5  \
# 0       105.571941            8.319302             678.044754
# 1        88.628668            9.519728            3595.619311
# 2        66.221647            4.047778             931.561885
# 3        67.181323           36.912815             518.289467
# 4       194.049032          102.131069            1373.345415
# ..             ...                 ...                    ...
# 268     162.107135           25.813238            1139.911459
# 269      10.969504            0.466589              32.231382
# 270      68.331035           73.175235             685.728600
# 271     153.178968            3.777999             448.127116
# 272     222.140519            0.721589            1325.213425
#
#      Women_Children_under5_norm  Women_Children_under18  \
# 0                     53.431423              751.411465
# 1                    386.210452             3650.855658
# 2                     56.941436             1117.787128
# 3                    284.774433              533.151065
# 4                    722.813376             1448.205036
# ..                          ...                     ...
# 268                  181.514563             1215.161059
# 269                    1.370965               38.596403
# 270                  734.342044              791.463616
# 271                   11.052586              488.517464
# 272                    4.304751             1388.342874
#
#      Women_Children_under18_norm
# 0                      59.212881
# 1                     392.143465
# 2                      68.324397
# 3                     292.940145
# 4                     762.213177
# ..                           ...
# 268                   193.496984
# 269                     1.641702
# 270                   847.572945
# 271                    12.048772
# 272                     4.509817
#
# [273 rows x 32 columns]

# %% [markdown]
# #### A dataframe is created with the 'acess_data' geoshapefile. This dataframe is cleaned up and the values are convereted into integers. Finally, we export the dataframe into a csv file and a shapefile.

# %%
age_access_data.columns
# Out:
# Index(['LOCATION_N', 'geometry', 'Total_pop_', 'Totalpop_served',
#        'Males_served', 'Males_served_Under5', 'Males_served_Under18',
#        'Males_served_Over65', 'Females_served', 'Females_served_Under5',
#        'Females_served_Under18', 'Females_served_Over65', 'ASSET_SIZE',
#        'Totalpop_served_norm', 'Males_served_norm', 'Males_served_Under5_norm',
#        'Males_served_Under18_norm', 'Males_served_Over65_norm',
#        'Females_served_norm', 'Females_served_Under5_norm',
#        'Females_served_Under18_norm', 'Females_served_Over65_norm',
#        'Under5_served', 'Under5_served_norm', 'Under18_served',
#        'Under18_served_norm', 'Over65_served', 'Over65_served_norm',
#        'Women_Children_under5', 'Women_Children_under5_norm',
#        'Women_Children_under18', 'Women_Children_under18_norm'],
#       dtype='object')

# %%
df = pd.DataFrame(age_access_data)
df['Park_Name']=df['LOCATION_N']

df['Totalpop_served'] = df['Totalpop_served'].astype(int)
df['Totalpop_served_norm'] = df['Totalpop_served_norm'].astype(int)

df['Males_served'] = df['Males_served'].astype(int)
df['Males_served_norm'] = df['Males_served_norm'].astype(int)

df['Males_served_Under5'] = df['Males_served_Under5'].astype(int)
df['Males_served_Under5_norm'] = df['Males_served_Under5_norm'].astype(int)

df['Males_served_Under18'] = df['Males_served_Under18'].astype(int)
df['Males_served_Under18_norm'] = df['Males_served_Under18_norm'].astype(int)

df['Males_served_Over65'] = df['Males_served_Over65'].astype(int)
df['Males_served_Over65_norm'] = df['Males_served_Over65_norm'].astype(int)

df['Females_served'] = df['Females_served'].astype(int)
df['Females_served_norm'] = df['Females_served_norm'].astype(int)

df['Females_served_Under5'] = df['Females_served_Under5'].astype(int)
df['Females_served_Under5_norm'] = df['Females_served_Under5_norm'].astype(int)

df['Females_served_Under18'] = df['Females_served_Under18'].astype(int)
df['Females_served_Under18_norm'] = df['Females_served_Under18_norm'].astype(int)

df['Females_served_Over65'] = df['Females_served_Over65'].astype(int)
df['Females_served_Over65_norm'] = df['Females_served_Over65_norm'].astype(int)

df['Under5_served'] = df['Under5_served'].astype(int)
df['Under5_served_norm'] = df['Under5_served_norm'].astype(int)

df['Under18_served'] = df['Under18_served'].astype(int)
df['Under18_served_norm'] = df['Under18_served_norm'].astype(int)

df['Over65_served'] = df['Over65_served'].astype(int)
df['Over65_served_norm'] = df['Over65_served_norm'].astype(int)

df['Women_Children_under5']= df['Women_Children_under5'].astype(int)
df['Women_Children_under5_norm']= df['Women_Children_under5_norm'].astype(int)

df['Women_Children_under18']= df['Women_Children_under18'].astype(int)
df['Women_Children_under18_norm']= df['Women_Children_under18_norm'].astype(int)

# %%
df.columns
# Out:
# Index(['LOCATION_N', 'geometry', 'Total_pop_', 'Totalpop_served',
#        'Males_served', 'Males_served_Under5', 'Males_served_Under18',
#        'Males_served_Over65', 'Females_served', 'Females_served_Under5',
#        'Females_served_Under18', 'Females_served_Over65', 'ASSET_SIZE',
#        'Totalpop_served_norm', 'Males_served_norm', 'Males_served_Under5_norm',
#        'Males_served_Under18_norm', 'Males_served_Over65_norm',
#        'Females_served_norm', 'Females_served_Under5_norm',
#        'Females_served_Under18_norm', 'Females_served_Over65_norm',
#        'Under5_served', 'Under5_served_norm', 'Under18_served',
#        'Under18_served_norm', 'Over65_served', 'Over65_served_norm',
#        'Women_Children_under5', 'Women_Children_under5_norm',
#        'Women_Children_under18', 'Women_Children_under18_norm', 'Park_Name'],
#       dtype='object')

# %%
access_age_final = df.copy()
access_age_final = gpd.GeoDataFrame(access_age_final, geometry='geometry')
access_age_final.to_file(wd+"data/access/access_age_final_quarterbuff_ACS17.shp")
access_age_final.head()
# Out:
#                          LOCATION_N  \
# 0    A.B. Dittmar Neighborhood Park
# 1  Adams-Hemphill Neighborhood Park
# 2           Agave Neighborhood Park
# 3                 Alamo Pocket Park
# 4            Alderbrook Pocket Park
#
#                                             geometry  Total_pop_  \
# 0  POLYGON ((3097945.260486613 10040357.04514253,...        6628
# 1  POLYGON ((3116425.666618853 10079471.33829271,...       21048
# 2  (POLYGON ((3145065.384555357 10081869.95696411...        6201
# 3  POLYGON ((3122655.295172911 10075520.37048018,...        6559
# 4  POLYGON ((3128917.516225351 10124262.76067684,...        5332
#
#    Totalpop_served  Males_served  Males_served_Under5  Males_served_Under18  \
# 0             1273           653                   58                   131
# 1             6561          2965                    4                    59
# 2             1605           786                  119                   306
# 3             1125           625                   17                    32
# 4             2304           974                   44                   119
#
#    Males_served_Over65  Females_served  Females_served_Under5  ...  \
# 0                   48             619                     25  ...
# 1                   75            3590                     71  ...
# 2                   27             811                    111  ...
# 3                   23             500                     16  ...
# 4                   17            1328                     83  ...
#
#    Under5_served_norm  Under18_served  Under18_served_norm  Over65_served  \
# 0                   6             209                   16            105
# 1                   8             252                   27             88
# 2                  14             653                   39             66
# 3                  18              83                   46             67
# 4                  67             329                  173            194
#
#    Over65_served_norm  Women_Children_under5  Women_Children_under5_norm  \
# 0                   8                    678                          53
# 1                   9                   3595                         386
# 2                   4                    931                          56
# 3                  36                    518                         284
# 4                 102                   1373                         722
#
#    Women_Children_under18  Women_Children_under18_norm  \
# 0                     751                           59
# 1                    3650                          392
# 2                    1117                           68
# 3                     533                          292
# 4                    1448                          762
#
#                           Park_Name
# 0    A.B. Dittmar Neighborhood Park
# 1  Adams-Hemphill Neighborhood Park
# 2           Agave Neighborhood Park
# 3                 Alamo Pocket Park
# 4            Alderbrook Pocket Park
#
# [5 rows x 33 columns]

# %%
access_agetable = df.drop(columns=['geometry'])
access_agetable.to_csv(wd+"data/access/access_table_age_quarterbuff_ACS17.csv")
access_agetable.head()
# Out:
#                          LOCATION_N  Total_pop_  Totalpop_served  \
# 0    A.B. Dittmar Neighborhood Park        6628             1273
# 1  Adams-Hemphill Neighborhood Park       21048             6561
# 2           Agave Neighborhood Park        6201             1605
# 3                 Alamo Pocket Park        6559             1125
# 4            Alderbrook Pocket Park        5332             2304
#
#    Males_served  Males_served_Under5  Males_served_Under18  \
# 0           653                   58                   131
# 1          2965                    4                    59
# 2           786                  119                   306
# 3           625                   17                    32
# 4           974                   44                   119
#
#    Males_served_Over65  Females_served  Females_served_Under5  \
# 0                   48             619                     25
# 1                   75            3590                     71
# 2                   27             811                    111
# 3                   23             500                     16
# 4                   17            1328                     83
#
#    Females_served_Under18  ...  Under5_served_norm  Under18_served  \
# 0                      78  ...                   6             209
# 1                     192  ...                   8             252
# 2                     347  ...                  14             653
# 3                      51  ...                  18              83
# 4                     210  ...                  67             329
#
#    Under18_served_norm  Over65_served  Over65_served_norm  \
# 0                   16            105                   8
# 1                   27             88                   9
# 2                   39             66                   4
# 3                   46             67                  36
# 4                  173            194                 102
#
#    Women_Children_under5  Women_Children_under5_norm  Women_Children_under18  \
# 0                    678                          53                     751
# 1                   3595                         386                    3650
# 2                    931                          56                    1117
# 3                    518                         284                     533
# 4                   1373                         722                    1448
#
#    Women_Children_under18_norm                         Park_Name
# 0                           59    A.B. Dittmar Neighborhood Park
# 1                          392  Adams-Hemphill Neighborhood Park
# 2                           68           Agave Neighborhood Park
# 3                          292                 Alamo Pocket Park
# 4                          762            Alderbrook Pocket Park
#
# [5 rows x 32 columns]

# %%
access_age_stats = access_agetable.describe()
access_age_stats.to_csv(wd+"data/access/access_stats_age_quarterbuff_ACS17.csv")
access_age_stats
# Out:
#          Total_pop_  Totalpop_served  Males_served  Males_served_Under5  \
# count    273.000000       273.000000    273.000000           273.000000
# mean   10036.963370      1967.131868    961.820513            64.512821
# std     6411.120729      1956.230494    976.727761            75.734885
# min     2764.000000         0.000000      0.000000             0.000000
# 25%     6164.000000      1049.000000    478.000000            16.000000
# 50%     8242.000000      1429.000000    736.000000            44.000000
# 75%    11947.000000      2270.000000   1099.000000            81.000000
# max    54016.000000     17684.000000   9254.000000           611.000000
#
#        Males_served_Under18  Males_served_Over65  Females_served  \
# count            273.000000           273.000000      273.000000
# mean             198.765568            72.355311      901.219780
# std              224.163174            75.198036      919.509386
# min                0.000000             0.000000        0.000000
# 25%               67.000000            33.000000      453.000000
# 50%              134.000000            55.000000      686.000000
# 75%              221.000000            88.000000     1090.000000
# max             1531.000000           621.000000     8417.000000
#
#        Females_served_Under5  Females_served_Under18  Females_served_Over65  \
# count             273.000000              273.000000             273.000000
# mean               61.014652              191.457875              91.183150
# std                71.893404              212.024951              89.367937
# min                 0.000000                0.000000               0.000000
# 25%                20.000000               78.000000              44.000000
# 50%                38.000000              127.000000              68.000000
# 75%                74.000000              218.000000             113.000000
# max               599.000000             1664.000000             780.000000
#
#        ...  Under5_served  Under5_served_norm  Under18_served  \
# count  ...     273.000000          273.000000      273.000000
# mean   ...     125.992674           40.805861      390.684982
# std    ...     142.862516          113.607469      431.842108
# min    ...       0.000000            0.000000        0.000000
# 25%    ...      42.000000            3.000000      155.000000
# 50%    ...      85.000000            9.000000      265.000000
# 75%    ...     165.000000           25.000000      428.000000
# max    ...    1211.000000         1298.000000     3196.000000
#
#        Under18_served_norm  Over65_served  Over65_served_norm  \
# count           273.000000     273.000000          273.000000
# mean            126.575092     164.021978           61.630037
# std             421.207328     161.542722          243.725102
# min               0.000000       0.000000            0.000000
# 25%              10.000000      80.000000            6.000000
# 50%              29.000000     124.000000           17.000000
# 75%              82.000000     194.000000           42.000000
# max            5709.000000    1385.000000         3305.000000
#
#        Women_Children_under5  Women_Children_under5_norm  \
# count             273.000000                  273.000000
# mean              966.241758                  324.589744
# std               979.889621                  808.910660
# min                 0.000000                    0.000000
# 25%               479.000000                   29.000000
# 50%               721.000000                  101.000000
# 75%              1164.000000                  266.000000
# max              8709.000000                10220.000000
#
#        Women_Children_under18  Women_Children_under18_norm
# count              273.000000                   273.000000
# mean              1100.498168                   367.655678
# std               1105.609990                   923.161332
# min                  0.000000                     0.000000
# 25%                568.000000                    32.000000
# 50%                797.000000                   115.000000
# 75%               1324.000000                   300.000000
# max               9336.000000                 11168.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# ### END OF CODE
