# %%
import geopandas as gpd
import pandas as pd
import os
import getpass
import matplotlib.pyplot as plt
from earthpy.clip import clip_shp

# %% [markdown]
# ### NOTES:
# * Bring in parks buffer shapefiles
# * If everything is in the same coordinate system then do the areas generated convert as well?
# * What is the differene between bringing in a geojson vs. a shapefile?

# %% [markdown]
# ###### Bring in necessary geojson files and set your projection for all files

# %%
wd = os.getcwd()
wd = wd[:wd.find('notebooks')]

#crs is set for Central Texas
crs =  {'init' :'epsg:6578'}

parks = gpd.read_file(wd+"data/coaparks/parkboundaries.geojson")
parks = parks.to_crs(crs).explode().reset_index()

quartbuff = gpd.read_file(wd+"data/coaparks_buffer/quarterbuff.shp")
quartbuff.crs={'init' :'epsg:6578'}

pop = gpd.read_file(wd+"data/blockgroups_censusdata/popmerge.shp")
pop = pop.to_crs(crs).explode().reset_index()

race = gpd.read_file(wd+"data/blockgroups_censusdata/racemerge.shp")
race = race.to_crs(crs).explode().reset_index()

# %% [markdown]
# ##### Check your projections
# https://geopandas.org/projections.html

# %%
parks.crs
# Out:
# {'init': 'epsg:6578'}

# %%
quartbuff.crs
# Out:
# {'init': 'epsg:6578'}

# %%
pop.crs
# Out:
# {'init': 'epsg:6578'}

# %%
race.crs
# Out:
# {'init': 'epsg:6578'}

# %% [markdown]
# ###### Preview the files and clean the data

# %%
pop['fullarea_pop'] = pop['geometry'].area

# %%
pop.head()
# Out:
#    level_0  level_1       GEOID10   ALAND10  AWATER10   INTPTLAT10  \
# 0        0        0  482090109011  291268.0       0.0  +30.1776997
# 1        0        1  482090109011  291268.0       0.0  +30.1776997
# 2        1        0  482090109081  142299.0       0.0  +30.0960389
# 3        2        0  484530001011   17128.0       0.0  +30.3353452
# 4        3        0  484530001012   43720.0       0.0  +30.3247732
#
#      INTPTLON10       city_name           jurisdicti                     Id  \
# 0  -097.9267996  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109011
# 1  -097.9267996  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109011
# 2  -097.8116716  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109081
# 3  -097.7546582  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001011
# 4  -097.7516364  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001012
#
#             Id2  Total_POP                                           geometry  \
# 0  482090109011       2205  POLYGON ((3069238.317597141 10028016.9612432, ...
# 1  482090109011       2205  POLYGON ((3060340.445818828 10029833.26098835,...
# 2  482090109081       3774  POLYGON ((3093548.488136804 10008631.07120929,...
# 3  484530001011       1045  POLYGON ((3111310.380106392 10089474.08471978,...
# 4  484530001012       1202  POLYGON ((3109356.370562974 10091521.99532213,...
#
#    fullarea_pop
# 0  3.246546e+06
# 1  1.955842e+07
# 2  1.837684e+03
# 3  1.023445e+07
# 4  1.190644e+07

# %%
race['fullarea_race'] = race['geometry'].area
race.head()
# Out:
#    level_0  level_1       GEOID10   ALAND10  AWATER10   INTPTLAT10  \
# 0        0        0  482090109011  291268.0       0.0  +30.1776997
# 1        0        1  482090109011  291268.0       0.0  +30.1776997
# 2        1        0  482090109081  142299.0       0.0  +30.0960389
# 3        2        0  484530001011   17128.0       0.0  +30.3353452
# 4        3        0  484530001012   43720.0       0.0  +30.3247732
#
#      INTPTLON10       city_name           jurisdicti                     Id  \
# 0  -097.9267996  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109011
# 1  -097.9267996  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109011
# 2  -097.8116716  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US482090109081
# 3  -097.7546582  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001011
# 4  -097.7516364  CITY OF AUSTIN  AUSTIN FULL PURPOSE  1500000US484530001012
#
#    ... Black or A  American I  Asian; Not  Native Haw  Some other  Two or mor  \
# 0  ...          0           0          40          78           0          34
# 1  ...          0           0          40          78           0          34
# 2  ...         91           0          80           0           0          16
# 3  ...         26           0           0           0           0          20
# 4  ...          0          14           0           0           0          42
#
#    Hispanic o  Sum of Non                                           geometry  \
# 0         421        2205  POLYGON ((3069238.317597141 10028016.9612432, ...
# 1         421        2205  POLYGON ((3060340.445818828 10029833.26098835,...
# 2        2507        3774  POLYGON ((3093548.488136804 10008631.07120929,...
# 3         113        1045  POLYGON ((3111310.380106392 10089474.08471978,...
# 4         121        1202  POLYGON ((3109356.370562974 10091521.99532213,...
#
#    fullarea_race
# 0   3.246546e+06
# 1   1.955842e+07
# 2   1.837684e+03
# 3   1.023445e+07
# 4   1.190644e+07
#
# [5 rows x 24 columns]

# %%
quartbuff['fullarea_buff'] = quartbuff['geometry'].area
quartbuff.head()
# Out:
#   ASSET_MGMT                         LOCATION_N  \
# 0        412       Stratford Overlook Greenbelt
# 1        413         Highland Neighborhood Park
# 2        354            Palma Plaza Pocket Park
# 3        398           Oertli Neighborhood Park
# 4        370  Decker Tallgrass Prairie Preserve
#
#                                     ADDRESS CITY_MUNIC  COUNTY STATE  \
# 0   3006 Stratford Dr., Austin, Texas 78746     Austin  Travis    TX
# 1  403 W St Johns Ave., Austin, Texas 78752     Austin  Travis    TX
# 2      1524 Palma Plz., Austin, Texas 78703     Austin  Travis    TX
# 3     12613 Blaine Rd., Austin, Texas 78753     Austin  Travis    TX
# 4      8001 Decker Ln., Austin, Texas 78724     Austin  Travis    TX
#
#   STREET_NUM  STREET_NAM STREET_TYP ZIPCODE  ...  MXLOADID GLOBALID  \
# 0       3006   Stratford        Dr.   78746  ...      None     None
# 1        403  W St Johns       Ave.   78752  ...      None     None
# 2       1524       Palma        Plz   78703  ...      None     None
# 3      12613      Blaine        Rd.   78753  ...      None     None
# 4       8001      Decker        Ln.   78724  ...      None     None
#
#       CREATED_BY  CREATED_DA     MODIFIED_B  MODIFIED_D    Shape__Are  \
# 0  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  4.403262e+03
# 1  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  1.048800e+04
# 2  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  1.007678e+04
# 3  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  2.671883e+05
# 4  CTM.Publisher  2019-10-12  CTM.Publisher  2019-10-12  1.515843e+07
#
#      Shape__Len                                           geometry  \
# 0    420.672106  POLYGON ((3099659.296639044 10076099.36654302,...
# 1    422.279483  POLYGON ((3122902.889064272 10096179.9084496, ...
# 2    492.661534  POLYGON ((3109810.268547321 10075962.94345399,...
# 3   2404.916487  POLYGON ((3142020.189037629 10117140.78761702,...
# 4  26672.772067  POLYGON ((3154723.006204365 10083882.87548335,...
#
#   fullarea_buff
# 0  6.701295e+05
# 1  6.708336e+05
# 2  6.988492e+05
# 3  1.463807e+06
# 4  9.294015e+06
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Run spatial analysis on the amount of people distributed within a census block group against park buffer area

# %%
rp_intersection = gpd.overlay(race, quartbuff, how='intersection') #https://geopandas.org/set_operations.html
rp_intersection
# Out:
#       level_0  level_1       GEOID10   ALAND10  AWATER10   INTPTLAT10  \
# 1           2        0  484530001011   17128.0       0.0  +30.3353452
# 6           4        0  484530001013  415563.0       0.0  +30.3158528
# 20          8        0  484530002041   57831.0       0.0  +30.3027360
# 23          9        0  484530002042   16538.0       0.0  +30.3162020
# 29         10        0  484530002043   61172.0       0.0  +30.3084751
# ...       ...      ...           ...       ...       ...          ...
# 1592      542        0  484910204083   34157.0       0.0  +30.4530947
# 1590      540        0  484910204081    9762.0       0.0  +30.4597401
# 1593      552        2  484910205081  636722.0     850.0  +30.4840639
# 1597      556        0  484910205101    2092.0       0.0  +30.4950296
# 1599      557        0  484910205103   14153.0       0.0  +30.4953417
#
#         INTPTLON10       city_name           jurisdicti  \
# 1     -097.7546582  CITY OF AUSTIN  AUSTIN FULL PURPOSE
# 6     -097.7515898  CITY OF AUSTIN  AUSTIN FULL PURPOSE
# 20    -097.7413860  CITY OF AUSTIN  AUSTIN FULL PURPOSE
# 23    -097.7451126  CITY OF AUSTIN  AUSTIN FULL PURPOSE
# 29    -097.7470902  CITY OF AUSTIN  AUSTIN FULL PURPOSE
# ...            ...             ...                  ...
# 1592  -097.7811364  CITY OF AUSTIN  AUSTIN FULL PURPOSE
# 1590  -097.7933842  CITY OF AUSTIN  AUSTIN FULL PURPOSE
# 1593  -097.7595422  CITY OF AUSTIN  AUSTIN FULL PURPOSE
# 1597  -097.7673875  CITY OF AUSTIN  AUSTIN FULL PURPOSE
# 1599  -097.7716305  CITY OF AUSTIN  AUSTIN FULL PURPOSE
#
#                          Id  ... MXLOADID  GLOBALID     CREATED_BY  \
# 1     1500000US484530001011  ...     None      None  CTM.Publisher
# 6     1500000US484530001013  ...     None      None  CTM.Publisher
# 20    1500000US484530002041  ...     None      None  CTM.Publisher
# 23    1500000US484530002042  ...     None      None  CTM.Publisher
# 29    1500000US484530002043  ...     None      None  CTM.Publisher
# ...                     ...  ...      ...       ...            ...
# 1592  1500000US484910204083  ...     None      None  CTM.Publisher
# 1590  1500000US484910204081  ...     None      None  CTM.Publisher
# 1593  1500000US484910205081  ...     None      None  CTM.Publisher
# 1597  1500000US484910205101  ...     None      None  CTM.Publisher
# 1599  1500000US484910205103  ...     None      None  CTM.Publisher
#
#       CREATED_DA     MODIFIED_B  MODIFIED_D    Shape__Are    Shape__Len  \
# 1     2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06  56641.286637
# 6     2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06  56641.286637
# 20    2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06  56641.286637
# 23    2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06  56641.286637
# 29    2019-10-12  CTM.Publisher  2019-10-12  3.514350e+06  56641.286637
# ...          ...            ...         ...           ...           ...
# 1592  2019-10-12  CTM.Publisher  2019-10-12  5.423833e+05   2970.882179
# 1590  2019-10-12  CTM.Publisher  2019-10-12  9.810471e+04   1492.002528
# 1593  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05   3819.975953
# 1597  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05   3819.975953
# 1599  2019-10-12  CTM.Publisher  2019-10-12  6.289057e+05   3819.975953
#
#       fullarea_buff                                           geometry
# 1      2.083222e+07  (POLYGON ((3112577.691601556 10092106.43546127...
# 6      2.083222e+07  (POLYGON ((3111956.64230204 10087345.37179527,...
# 20     2.083222e+07  POLYGON ((3112579.183619359 10081465.39038167,...
# 23     2.083222e+07  (POLYGON ((3112506.819622439 10086223.64617552...
# 29     2.083222e+07  (POLYGON ((3112746.76010764 10081979.97962928,...
# ...             ...                                                ...
# 1592   1.690157e+06  POLYGON ((3099958.623058978 10137136.64832762,...
# 1590   1.070334e+06  POLYGON ((3100175.699942151 10143570.94554518,...
# 1593   1.976420e+06  (POLYGON ((3104261.391998203 10149293.93935596...
# 1597   1.976420e+06  POLYGON ((3105146.529438308 10149196.16067607,...
# 1599   1.976420e+06  (POLYGON ((3104692.752993943 10150897.72012688...
#
# [943 rows x 78 columns]

# %%
rp_intersection.columns
# Out:
# Index(['level_0', 'level_1', 'GEOID10', 'ALAND10', 'AWATER10', 'INTPTLAT10',
#        'INTPTLON10', 'city_name', 'jurisdicti', 'Id', 'Id2', 'Total_POP',
#        'Not Hispan', 'White; Not', 'Black or A', 'American I', 'Asian; Not',
#        'Native Haw', 'Some other', 'Two or mor', 'Hispanic o', 'Sum of Non',
#        'fullarea_race', 'ASSET_MGMT', 'LOCATION_N', 'ADDRESS', 'CITY_MUNIC',
#        'COUNTY', 'STATE', 'STREET_NUM', 'STREET_NAM', 'STREET_TYP', 'ZIPCODE',
#        'ASSET_SIZE', 'ACRE_SOURC', 'UNIT_OF_ME', 'YEAR_ACQUI', 'ASSET_STAT',
#        'DEVELOPMEN', 'TPL_LANDUS', 'PARK_TYPE', 'LEVEL_OF_S', 'LEVEL_OF_U',
#        'SERVICE_AR', 'COUNCIL_DI', 'COUNCIL__1', 'MANAGEMENT', 'OWNER_NAME',
#        'OWNER_TYPE', 'MANAGING_N', 'MANAGING_T', 'ACQUISITIO', 'ACQUISIT_1',
#        'ACQUISIT_2', 'DEVELOPM_1', 'DEVELOPM_2', 'RESTRICTIO', 'LWCF_PROTE',
#        'OTHER_PROT', 'REST_PROT_', 'COMMUNITY_', 'MXASSETNUM', 'MXLOCATION',
#        'MXSITEID', 'MXCREATION', 'MXSTATUS', 'MXCONDITIO', 'MXPRIORITY',
#        'MXLOADID', 'GLOBALID', 'CREATED_BY', 'CREATED_DA', 'MODIFIED_B',
#        'MODIFIED_D', 'Shape__Are', 'Shape__Len', 'fullarea_buff', 'geometry'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(12,12))
base = rp_intersection.plot(ax=ax, color="black", alpha=0.2)
layer = rp_intersection["geometry"].plot(ax=base, color='black', edgecolor = 'black')

# %%
rp_intersection[['GEOID10','Total_POP','fullarea_race','LOCATION_N','fullarea_buff','geometry']]
# Out:
#            GEOID10  Total_POP  fullarea_race                      LOCATION_N  \
# 1     484530001011       1045   1.023445e+07           Shoal Creek Greenbelt
# 6     484530001013       2016   1.151098e+07           Shoal Creek Greenbelt
# 20    484530002041       1113   5.533474e+06           Shoal Creek Greenbelt
# 23    484530002042       1255   5.936942e+06           Shoal Creek Greenbelt
# 29    484530002043        692   8.170845e+06           Shoal Creek Greenbelt
# ...            ...        ...            ...                             ...
# 1592  484910204083        835   9.487768e+05   Springwoods Neighborhood Park
# 1590  484910204081       1797   1.660166e+07  Forest North Neighborhood Park
# 1593  484910205081       3775   3.664291e+07       Davis Spring Special Park
# 1597  484910205101       4695   3.462268e+07       Davis Spring Special Park
# 1599  484910205103        929   3.727163e+06       Davis Spring Special Park
#
#       fullarea_buff                                           geometry
# 1      2.083222e+07  (POLYGON ((3112577.691601556 10092106.43546127...
# 6      2.083222e+07  (POLYGON ((3111956.64230204 10087345.37179527,...
# 20     2.083222e+07  POLYGON ((3112579.183619359 10081465.39038167,...
# 23     2.083222e+07  (POLYGON ((3112506.819622439 10086223.64617552...
# 29     2.083222e+07  (POLYGON ((3112746.76010764 10081979.97962928,...
# ...             ...                                                ...
# 1592   1.690157e+06  POLYGON ((3099958.623058978 10137136.64832762,...
# 1590   1.070334e+06  POLYGON ((3100175.699942151 10143570.94554518,...
# 1593   1.976420e+06  (POLYGON ((3104261.391998203 10149293.93935596...
# 1597   1.976420e+06  POLYGON ((3105146.529438308 10149196.16067607,...
# 1599   1.976420e+06  (POLYGON ((3104692.752993943 10150897.72012688...
#
# [943 rows x 6 columns]

# %%
race[['GEOID10','Total_POP','fullarea_race','geometry']]
# Out:
#           GEOID10  Total_POP  fullarea_race  \
# 0    482090109011       2205   3.246546e+06
# 1    482090109011       2205   1.955842e+07
# 2    482090109081       3774   1.837684e+03
# 3    484530001011       1045   1.023445e+07
# 4    484530001012       1202   1.190644e+07
# ..            ...        ...            ...
# 663  484910205082       1264   8.239788e+06
# 664  484910205091       2504   1.948094e+07
# 665  484910205093       3192   1.100151e+07
# 666  484910205101       4695   3.462268e+07
# 667  484910205103        929   3.727163e+06
#
#                                               geometry
# 0    POLYGON ((3069238.317597141 10028016.9612432, ...
# 1    POLYGON ((3060340.445818828 10029833.26098835,...
# 2    POLYGON ((3093548.488136804 10008631.07120929,...
# 3    POLYGON ((3111310.380106392 10089474.08471978,...
# 4    POLYGON ((3109356.370562974 10091521.99532213,...
# ..                                                 ...
# 663  POLYGON ((3100132.260730391 10153583.0096513, ...
# 664  POLYGON ((3103596.356820557 10154673.60851996,...
# 665  POLYGON ((3111608.114134965 10157930.24793256,...
# 666  POLYGON ((3105356.685648966 10148942.41788262,...
# 667  POLYGON ((3104338.228040222 10151913.94934112,...
#
# [668 rows x 4 columns]

# %%
figrace, ax = plt.subplots(figsize=(12,12))
base = race.plot(ax=ax, color="black", alpha=0.2)
layer = race["geometry"].plot(ax=base, color='white', edgecolor = 'black')

# %%
access_data = {'Park_Name':[],
       'Calc_Pop':[]}

pop_clip=rp_intersection.copy()

if park in rp_intersection:

        pop_clip['new_area'] = pop_clip['geometry'].area
        pop_clip['weight'] = pop_clip['new_area']/ pop_clip['full_area']
        pop_clip['new_pop'] = pop_clip['weight'] * pop_clip['Estimate;']

        data['Park_Name'].append(name)
        data['Calc_Pop'].append(pop_clip['new_pop'].sum())
    else: # if no pop blocks are within the park then return 0
        data['Park_Name'].append(name)
        data['Calc_Pop'].append(0)

# %%
data = {'Park_Name':[],
       'Calc_Pop':[]}

from shapely.geometry import Polygon
names = quartbuff['LOCATION_N'].unique()
for i, dfrow in parks.iterrows():
     name = dfrow['LOCATION_N']

for i,name in enumerate(names):
    park = quartbuff.loc[quartbuff['LOCATION_N'] == name]
    park['geometry'] = park['geometry'].buffer(0) #This is the buffer
#     print(i, name)
    
    is_in_park = False
    for j, dfrow in pop.iterrows(): # iterate over pop shapes
#         print(dfrow['geometry'].is_valid)
        for n, dfrow2 in park.iterrows(): # iterate over buffered park shape
            # check if any pop shps fall within the buffered park shapes
            if Polygon(dfrow['geometry']).intersects(Polygon(dfrow2['geometry'])):
                is_in_park = True
                break
    if is_in_park:
        pop_valid = pop.copy()
        pop_valid['geometry'] = pop_valid['geometry'].buffer(0) # fix invalid polygons by buffering them by zero distances
        # definetly a hack and should be looked into.
        pop_clip = clip_shp(pop_valid,park)

        pop_clip['new_area'] = pop_clip['geometry'].area
        pop_clip['weight'] = pop_clip['new_area']/ pop_clip['full_area']
        pop_clip['new_pop'] = pop_clip['weight'] * pop_clip['Estimate;']

        data['Park_Name'].append(name)
        data['Calc_Pop'].append(pop_clip['new_pop'].sum())
    else: # if no pop blocks are within the park then return 0
        data['Park_Name'].append(name)
        data['Calc_Pop'].append(0)

# print(park.head())

# %%
df = pd.DataFrame(data)
df['Calc_Pop'] = df['Calc_Pop'].astype(int)

df.head(10)

# %%
parkspop = df.copy()
quartbuff = gpd.read_file(wd+"data/coaparks_buffer/quarterbuffgj.geojson")
qbuff = quartbuff.copy()
parksnocem= qbuff.loc[~qbuff['LOCATION_N'].str.contains('Cemetery')].reset_index()
parks_pop = parksnocem.merge(parkspop, left_on='LOCATION_N', right_on='Park_Name', suffixes=('_parksnocem', '_parkspop'))
parks_pop.to_file(wd+"data/access/parks_pop_quarterbuff_ACS17.shp")

# %%
parks_pop

# %% [markdown]
# END OF CODE
