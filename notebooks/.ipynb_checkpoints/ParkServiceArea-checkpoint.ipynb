# %% [markdown]
# ## In this notebook we will create service area boundaries for each park managed by the city of austin

# %%
import geopandas as gpd
import os
import getpass
import matplotlib.pyplot as plt
import re
import pandas as pd

# %%
wd = os.getcwd()
wd = wd[:wd.find('notebooks')]


coaparks = gpd.read_file(wd+"data/coaparks/BOUNDARIES_city_of_austin_parks.shp")
coaparks.crs = {'init': 'epsg:102739'}
coaparks
# Out:
#     ASSET_MGMT                                         LOCATION_N  \
# 0          412                       Stratford Overlook Greenbelt
# 1          413                         Highland Neighborhood Park
# 2          354                            Palma Plaza Pocket Park
# 3          398                           Oertli Neighborhood Park
# 4          370                  Decker Tallgrass Prairie Preserve
# ..         ...                                                ...
# 298        423                        Red Bluff Neighborhood Park
# 299        420                      MLK Station Neighborhood Park
# 300        368  Louis Ren̩ Barrera Indiangrass Wildlife Sanct...
# 301        165                             Garrison District Park
# 302        424                          Davis Spring Special Park
#
#                                                ADDRESS CITY_MUNIC  COUNTY  \
# 0              3006 Stratford Dr., Austin, Texas 78746     Austin  Travis
# 1             403 W St Johns Ave., Austin, Texas 78752     Austin  Travis
# 2                 1524 Palma Plz., Austin, Texas 78703     Austin  Travis
# 3                12613 Blaine Rd., Austin, Texas 78753     Austin  Travis
# 4                 8001 Decker Ln., Austin, Texas 78724     Austin  Travis
# ..                                                 ...        ...     ...
# 298               5805 Harold Ct., Austin, Texas 78721     Austin  Travis
# 299  2907 E Martin Luther King Jr Blvd., Austin, Te...     Austin  Travis
# 300             10203 Lindell Ln., Austin, Texas 78724     Austin  Travis
# 301             6001 Menchaca Rd., Austin, Texas 78745     Austin  Travis
# 302          9901 1/2 Neenah Ave., Austin, Texas 78717     Austin  Travis
#
#     STATE STREET_NUM               STREET_NAM STREET_TYP ZIPCODE  ...  \
# 0      TX       3006                Stratford        Dr.   78746  ...
# 1      TX        403               W St Johns       Ave.   78752  ...
# 2      TX       1524                    Palma        Plz   78703  ...
# 3      TX      12613                   Blaine        Rd.   78753  ...
# 4      TX       8001                   Decker        Ln.   78724  ...
# ..    ...        ...                      ...        ...     ...  ...
# 298    TX       5805                   Harold        Ct.   78721  ...
# 299    TX       2907  E Martin Luther King Jr      Blvd.   78702  ...
# 300    TX      10203                  Lindell        Ln.   78724  ...
# 301    TX       6001                 Manchaca        Rd.   78745  ...
# 302    TX   9901 1/2                   Neenah       Ave.   78717  ...
#
#      MXPRIORITY MXLOADID GLOBALID     CREATED_BY  CREATED_DA     MODIFIED_B  \
# 0             0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
# 1             0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
# 2             0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
# 3             0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
# 4             0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
# ..          ...      ...      ...            ...         ...            ...
# 298           0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
# 299           0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
# 300           0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
# 301           0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
# 302           0     None     None  CTM.Publisher  2019-10-12  CTM.Publisher
#
#      MODIFIED_D    Shape__Are    Shape__Len  \
# 0    2019-10-12  4.403262e+03    420.672106
# 1    2019-10-12  1.048800e+04    422.279483
# 2    2019-10-12  1.007678e+04    492.661534
# 3    2019-10-12  2.671883e+05   2404.916487
# 4    2019-10-12  1.515843e+07  26672.772067
# ..          ...           ...           ...
# 298  2019-10-12  3.134473e+05   3463.806548
# 299  2019-10-12  3.358915e+05   4010.143616
# 300  2019-10-12  1.265950e+07  19783.547205
# 301  2019-10-12  1.718433e+06   6013.200084
# 302  2019-10-12  6.289057e+05   3819.975953
#
#                                               geometry
# 0    POLYGON ((3099906.430145308 10076413.89003989,...
# 1    POLYGON ((3123253.446115226 10095987.26952823,...
# 2    POLYGON ((3109560.790101632 10075621.8601279, ...
# 3    POLYGON ((3142167.801987216 10117512.55423348,...
# 4    POLYGON ((3155053.00948447 10084108.4848869, 3...
# ..                                                 ...
# 298  POLYGON ((3135145.072922468 10071838.69512206,...
# 299  POLYGON ((3125001.803182796 10074460.76008789,...
# 300  POLYGON ((3161502.230509892 10086758.05275048,...
# 301  POLYGON ((3096438.9803873 10050515.35030164, 3...
# 302  POLYGON ((3104769.340366974 10150475.19696948,...
#
# [303 rows x 54 columns]
